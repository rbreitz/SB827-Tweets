# %% [markdown]
# # Sentiment Analysis on SB 827
# California, particularly in coastal cities, has a really significant housing crisis. Recently, an ambitious bill was put forward in the California state senate that would have overrided local zoning laws in order to permit the construction of dense housing near frequent public transit stops. Unfortunately the bill died in committee before any real polling could be done to see whether the broader community wanted it. I thought I'd try to do some sentiment analysis on some Tweets on #SB827 in order to gauge support for the bill. Overall, 73% of the tweets in the set seemed to be supportive of the bill, with 72% of tweets from the West Coast and 75% of tweets from elsewhere expressing support of the bill. It seems likely that there is enough broad support that a similar bill could succeed in the future.

# %%
#import relevant packages
import tweepy
import sys
import jsonpickle
import os
import json
import numpy as np
import math
import pandas as pd
import textblob
import csv

# %% [markdown]
# ## Let's Go Grab a Bunch of Messy Data
# The goal of this section is to, with the assistance of Tweepy, grab a bunch of the tweets with the Seattle Hash Tag from the last month.

# %%
#add all of the authetication information
#also I should try to figure out how to make this non-legible later
consumer_key = ""
consumer_secret = ''
access_token = ""
access_token_secret = ''

# %%
#Create authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#Set access info
auth.set_access_token(access_token, access_token_secret)
#Make API
api = tweepy.API(auth, wait_on_rate_limit = True, wait_on_rate_limit_notify = True)

# %%
#Pull some tweets that hashtag SB 827

housing_query = "#SB827"
housing_tweets = api.search(q=housing_query, lang=language, count=100)

for tweet in housing_tweets:
    print tweet.user.screen_name, "Tweeted:", tweet.text
# Out:
# mtsw Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# Sightline Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# CaseyJGiven Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# thomas_lord Tweeted: @IDoTheThinking @suldrew @daguilarcanabal In the words of the great shootist Kim Carsons[*], TYT.  Take Your Time.… https://t.co/fnkJS77g7u
# hamilt0n Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# ZaxxonGalaxian Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# CarlMuhlstein Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# bayofarizona Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# mellamosonia Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# GoMaestra Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# jfbcasey Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# eb4everyone Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# JackSkelley Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# xavierkuai Tweeted: Friday thoughts while riding BART: let’s build more housing here. Let’s build more housing there. #SB827 https://t.co/4ZiSxgpfoV
# ndwollmann Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# JeffVoCRE Tweeted: RT @SVLeadershipGrp: .@SVLeadershipGrp strongly supports @Scott_Wiener's #SB827 — the most significant step forward on housing, transportat…
# andy_keatts Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# JaredMeyer10 Tweeted: RT @yvadv: New in @CityLab from @mnolangray: The defeat of #SB827, California’s ambitious pro-housing bill, masks a wider trend: Similar in…
# TheRealWBTC Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# huggafop Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# ChrisSchaper Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# EpiphyteCities Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# danafus Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# BoomCalifornia Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# happyann205 Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# KABRASS101 Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# DaytonPubPolicy Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# mmcphate Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# MatchewB Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# EthanElkind Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# bellwetherSF Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# gw_scott Tweeted: @omaryak In central urban locations such as #SF, #Oakland, #Berkeley and #SanJose that type of urban development wo… https://t.co/yYEOoBYPBW
# TahishaHewitt1 Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# xavierkuai Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# michael_hendrix Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# gw_scott Tweeted: @omaryak Good to know. There was a lot of confusion about #SB827. Some conversations indicated developers could buy… https://t.co/WNiHb54Se3
# marcslove Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# omaryak Tweeted: @gw_scott Almost certainly. The goal of #sb827 and bills like it would be to eliminate that empty space around high… https://t.co/vHUOUOf0UX
# gw_scott Tweeted: @omaryak Under #SB827 would this site would have qualified for high density, multi story housing?… https://t.co/pSGeQ6tz6m
# gw_scott Tweeted: @omaryak https://t.co/ecypWpBvO8
# Union City has it's own bus line and runs an extra line during the commute hours.… https://t.co/FUuS1qBXlP
# awalkerinLA Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# thecliffbar Tweeted: @CarthayCircleLA @StephanoMedina @dillonliam @planetmoney @elpaavo It's great that there are so many prosperous com… https://t.co/PBMHMeKrVa
# SFyimby Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# yimbyaction Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# AspieGrrrl Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# RobertGammon Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# peterpedroson Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# mc_lens Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# theeboyracer Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# SaveMeeJeebus Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# gw_scott Tweeted: @omaryak That could define every major street in the #BayArea. Does that mean #SB827 would allow 4 story housing si… https://t.co/eDI63rp5B6
# VTMichaels Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# lukescholefield Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# schroedinger_ Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# 530BruceRoss Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# Juan_Matute Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# UCLAZimanCenter Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# 42applesenergy Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# kvnweb Tweeted: RT @andrewsalzberg: Conservative take on #sb827: "Perhaps it’s because the dominant progressive voices in California are, in fact, regressi…
# elpaavo Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# smithtjosh Tweeted: RT @PolicyWilford: California NIMBYs successfully killed a promising effort to lower artificially high housing prices. #SB827 wasn't a pana…
# Parade_Time Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# smithtjosh Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# InmanAndrea Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# andrewsalzberg Tweeted: Conservative take on #sb827: "Perhaps it’s because the dominant progressive voices in California are, in fact, regr… https://t.co/pCBv3KlWRC
# alexzhao Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# mateosfo Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# PeteHarrisonNYC Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# junelin Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# adchamberlain Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# fabulavancouver Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# kimmaicutler Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# AshDHarrington Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# salimfurth Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# salimfurth Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# theoverheadwire Tweeted: RT @dillonliam: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel that st…
# dillonliam Tweeted: In @planetmoney’s take on #SB827 UCLA professor @elpaavo compares California’s single-family homeowners to a cartel… https://t.co/ax24prOaqZ
# novium258 Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# IDoTheThinking Tweeted: Forgive me if I'm wrong, I dont care for this super late to the party anti-#SB827 diatribe, but when @JaneKim says… https://t.co/1LwOmAnJDK
# sara_ela Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# 30BARACK Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# bestsidesf Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# SFHAC Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# SFHAC Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# el_maurilio Tweeted: RT @housingca: Latest News from Housing California: Updates on #SB918 #SB912 #SB827, @VetsAndHousing @AP_California's Census Policy Advocac…
# Andres4Seattle Tweeted: #SB827 (and the national media attention that it has garnered) has shifted the Overton window in the US. Thank you,… https://t.co/eOsotexlga
# HousingOC Tweeted: RT @cayimby: '@voxdotcom’s @mattyglesias called #SB827 “one of the most important ideas in American politics today.” And now it’s dead. But…
# charliebrown991 Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# no_durians Tweeted: RT @Shelterforce: We need to stop making believe that only developers are profiting from the urban housing shortage. https://t.co/E8CFqV37o…
# ChargerCarl Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# SimonCBird Tweeted: @JaneKim good piece in the @sfexaminer on #sb827, but what you miss is that SF families can't wait for a perfect bi… https://t.co/uJMnlw7S83
# eean Tweeted: RT @cayimby: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t…
# ChadMReese Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# CCCHTFP Tweeted: RT @housingca: Latest News from Housing California: Updates on #SB918 #SB912 #SB827, @VetsAndHousing @AP_California's Census Policy Advocac…
# cayimby Tweeted: Via @Slate: #SB827 “could have upended a century of racial housing politics.” Read &gt;&gt; https://t.co/TU6hi5Yt0J #SB827 https://t.co/JqUn9sCj3J
# YIMBYwiki Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# lizzywol Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# JohnMBianchi Tweeted: RT yvadv "RT mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underw… https://t.co/cU4VMi2BVL
# MarthaEkdahl Tweeted: RT @yvadv: New in @CityLab from @mnolangray: The defeat of #SB827, California’s ambitious pro-housing bill, masks a wider trend: Similar in…
# Stephen_Kent89 Tweeted: RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…

# %% [markdown]
# Alright, so that technique can't actually get us all that many tweets. Let's try implementing a solution from Bhaskar Karambelkar's Blog in order to get more efficient collection of the tweets.

# %%
maxTweets = 50000 #No particular reason for this
tweetsperQ = 100 #maximimum possible Tweets/Query
fName = 'SB827tweets.txt'
sinceId = None #Alter this later if you need a specific start data
max_id = -1L

tweetCount = 0
print ("Downloading max {} tweets".format(maxTweets))
with open(fName, 'w') as f:
    while tweetCount<maxTweets:
        try:
            if(max_id<=0):
                if(not sinceId):
                    new_tweets = api.search(q=housing_query, count=tweetsperQ)
                else:
                    new_tweets = api.search(q=housing_query, count=tweetsperQ, since_id=sinceId)
            else:
                if(not sinceId):
                    new_tweets = api.search(q=housing_query, count=tweetsperQ, max_id=str(max_id-1))
                else:
                    new_tweets = api.search(q=housing_query, count=tweetsperQ, max_id=str(mad_id-1), since_id=sinceId)
            if(not new_tweets):
                print("No more tweets found")
                break
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json, unpicklable=False)+'\n')
            tweetCount += len(new_tweets)
            print("Downloaded {} tweets".format(tweetCount))
            max_id = new_tweets[-1].id
        except tweepy.TweepError as e:
                print("Oh dear: "+str(e))
                break
print("Downloaded {} tweets".format(tweetCount))
# Out:
# Downloading max 50000 tweets
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 400 tweets
# Downloaded 500 tweets
# Downloaded 600 tweets
# Downloaded 700 tweets
# Downloaded 800 tweets
# Downloaded 900 tweets
# Downloaded 1000 tweets
# Downloaded 1100 tweets
# Downloaded 1200 tweets
# Downloaded 1300 tweets
# Downloaded 1400 tweets
# Downloaded 1500 tweets
# Downloaded 1600 tweets
# Downloaded 1700 tweets
# Downloaded 1800 tweets
# Downloaded 1900 tweets
# Downloaded 2000 tweets
# Downloaded 2100 tweets
# Downloaded 2200 tweets
# Downloaded 2278 tweets
# Downloaded 2378 tweets
# Downloaded 2478 tweets
# Downloaded 2578 tweets
# Downloaded 2678 tweets
# Downloaded 2778 tweets
# Downloaded 2878 tweets
# Downloaded 2978 tweets
# Downloaded 3078 tweets
# Downloaded 3178 tweets
# Downloaded 3278 tweets
# Downloaded 3378 tweets
# No more tweets found
# Downloaded 3378 tweets

# %% [markdown]
# ## Explore the tweets
# The goal of this section is to unpickle the tweets, try to figure out what information from them is likely to be worth keeping around, and then move the tweets to a dataframe and start looking at factors about how they were posted

# %%
#Load in a single tweet
SenateBillParsed = json.loads(f.readline())

# %%
#Examine the first level keys within that tweet
SenateBillParsed
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Fri Apr 27 21:28:03 +0000 2018',
#  u'entities': {u'hashtags': [{u'indices': [16, 22], u'text': u'SB827'}],
#   u'symbols': [],
#   u'urls': [],
#   u'user_mentions': [{u'id': 46818898,
#     u'id_str': u'46818898',
#     u'indices': [3, 14],
#     u'name': u'Nolan Gray \U0001f3d7\U0001f310',
#     u'screen_name': u'mnolangray'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 989979514246782982,
#  u'id_str': u'989979514246782982',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#  u'place': None,
#  u'retweet_count': 27,
#  u'retweeted': False,
#  u'retweeted_status': {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Apr 26 17:12:32 +0000 2018',
#   u'entities': {u'hashtags': [{u'indices': [0, 6], u'text': u'SB827'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#      u'expanded_url': u'https://twitter.com/i/web/status/989552820956344321',
#      u'indices': [116, 139],
#      u'url': u'https://t.co/gxuoNmUAVa'}],
#    u'user_mentions': []},
#   u'favorite_count': 49,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 989552820956344321,
#   u'id_str': u'989552820956344321',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 27,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u"#SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country.\u2026 https://t.co/gxuoNmUAVa",
#   u'truncated': True,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Jun 13 03:45:36 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Friendly neoliberal urbanist // Planning grad student @RutgersU // Advocate @yvadv // Bylines @marketurbanism @citylab // Kentuckian #BBN',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'marketurbanism.com/nolan-gray/',
#        u'expanded_url': u'http://marketurbanism.com/nolan-gray/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/ECBV0YcFP8'}]}},
#    u'favourites_count': 5568,
#    u'follow_request_sent': False,
#    u'followers_count': 1261,
#    u'following': False,
#    u'friends_count': 522,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 46818898,
#    u'id_str': u'46818898',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 45,
#    u'location': u'New Brunswick, NJ',
#    u'name': u'Nolan Gray \U0001f3d7\U0001f310',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/466396514021957632/V40VkJ6-.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/466396514021957632/V40VkJ6-.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/46818898/1524717846',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/929110744444080129/65aCtQ-Z_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/929110744444080129/65aCtQ-Z_normal.jpg',
#    u'profile_link_color': u'5B9A68',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'mnolangray',
#    u'statuses_count': 6364,
#    u'time_zone': u'Quito',
#    u'translator_type': u'none',
#    u'url': u'https://t.co/ECBV0YcFP8',
#    u'utc_offset': -18000,
#    u'verified': False}},
#  u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  u'text': u"RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates\u2026",
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Sun Feb 10 18:54:17 +0000 2013',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Philly lover.',
#   u'entities': {u'description': {u'urls': []}},
#   u'favourites_count': 118457,
#   u'follow_request_sent': False,
#   u'followers_count': 162,
#   u'following': False,
#   u'friends_count': 1905,
#   u'geo_enabled': False,
#   u'has_extended_profile': False,
#   u'id': 1166713243,
#   u'id_str': u'1166713243',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 0,
#   u'location': u'',
#   u'name': u'Colorfulharp233',
#   u'notifications': False,
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme13/bg.gif',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme13/bg.gif',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1166713243/1516230094',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/953764250610208768/Msz-jeJc_normal.jpg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/953764250610208768/Msz-jeJc_normal.jpg',
#   u'profile_link_color': u'981CEB',
#   u'profile_sidebar_border_color': u'000000',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'000000',
#   u'profile_use_background_image': False,
#   u'protected': False,
#   u'screen_name': u'colorfulharp233',
#   u'statuses_count': 6972,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'translator_type': u'none',
#   u'url': None,
#   u'utc_offset': -14400,
#   u'verified': False}}

# %%
#print some of the information that might be particularly interesting to keep around
print SenateBillParsed['user']['screen_name']
print SenateBillParsed['user']['time_zone']
print SenateBillParsed['text']
print SenateBillParsed['created_at']
print SenateBillParsed['user']['followers_count']
print SenateBillParsed['user']['location']
# Out:
# colorfulharp233
# Eastern Time (US & Canada)
# RT @mnolangray: #SB827's defeat was a bummer. But there are dozens of other major YIMBY initiatives underway all over the country. My lates…
# Fri Apr 27 21:28:03 +0000 2018
# 162

# %%
#Look at the sub-keys under the user key to see if anything else might be helpful
SenateBillParsed['user'].keys()
# Out:
# [u'follow_request_sent',
#  u'has_extended_profile',
#  u'profile_use_background_image',
#  u'id',
#  u'default_profile',
#  u'verified',
#  u'profile_text_color',
#  u'profile_image_url_https',
#  u'profile_sidebar_fill_color',
#  u'is_translator',
#  u'geo_enabled',
#  u'entities',
#  u'followers_count',
#  u'profile_sidebar_border_color',
#  u'location',
#  u'default_profile_image',
#  u'id_str',
#  u'is_translation_enabled',
#  u'utc_offset',
#  u'statuses_count',
#  u'description',
#  u'friends_count',
#  u'profile_link_color',
#  u'profile_image_url',
#  u'notifications',
#  u'profile_background_image_url_https',
#  u'profile_background_color',
#  u'profile_banner_url',
#  u'profile_background_image_url',
#  u'name',
#  u'lang',
#  u'profile_background_tile',
#  u'favourites_count',
#  u'screen_name',
#  u'url',
#  u'created_at',
#  u'contributors_enabled',
#  u'time_zone',
#  u'protected',
#  u'translator_type',
#  u'following',
#  u'listed_count']

# %%
columnslist = ['screen_name','time_zone','followers_count','location','text']
SBdf = pd.DataFrame(columns = columnslist)
fName = 'SB827tweets.txt'
f = open(fName, 'r+')
for line in f.readlines():
    new_tweet = json.loads(line)
    d = {'screen_name':[new_tweet['user']['screen_name']],
        'time_zone':[new_tweet['user']['time_zone']],
        'followers_count':[new_tweet['user']['followers_count']],
        'location':[new_tweet['user']['location']],
        'text':[new_tweet['text']]}
    new_tweet_df = pd.DataFrame(data=d)
    SBdf = SBdf.append(new_tweet_df, ignore_index=True)

# %%
SBdf.size
# Out:
# 16890

# %%
SBdf.columns
# Out:
# Index([u'followers_count', u'location', u'screen_name', u'text', u'time_zone'], dtype='object')

# %%
SBdf.time_zone.unique() #Examining the range of time zones that the tweets come from.
# Out:
# array([None, u'Eastern Time (US & Canada)', u'Pacific Time (US & Canada)',
#        u'Central Time (US & Canada)', u'Alaska', u'Arizona',
#        u'Atlantic Time (Canada)', u'Adelaide', u'America/New_York',
#        u'Quito', u'Tijuana', u'Tehran', u'America/Los_Angeles',
#        u'Amsterdam', u'Europe/London', u'Mountain Time (US & Canada)',
#        u'Hawaii', u'London', u'Paris', u'Stockholm', u'Berlin', u'Beijing',
#        u'Helsinki', u'Bern', u'Chennai', u'Dublin', u'Vilnius',
#        u'Pretoria', u'Azores', u'Tokyo', u'International Date Line West',
#        u'Central America', u'Kabul', u'Cairo', u'Madrid', u'PDT',
#        u'Brasilia', u'Casablanca', u'Perth', u'Karachi', u'Brisbane',
#        u'Santiago', u'Rome', u'Midway Island', u'Georgetown', u'Hong Kong',
#        u'Lima', u'Sydney', u'America/Chicago'], dtype=object)

# %%
SBdf.location.unique() #Examine the locations associated with the accounts
# Out:
# array([u'Beverly Hills, CA', u'', u'San Francisco', u'Arlington, VA',
#        u'Free Imperial City of San Francisco', u'San Francisco, CA',
#        u'Athens, Georgia', u'Beverly Hills, Stockholm', u'Brooklyn, NY',
#        u'Cascadia', u'Washington, D.C.', u'Oakland, Calif.', u'.',
#        u'Los Angeles', u'San Diego, CA', u'DC & CA', u'Empire State',
#        u'East Bay', u'Los Angeles, CA', u'San Jose, California',
#        u'San Diego', u'Washington D.C.', u'Westwood Park, San Francisco',
#        u'San Francisco, CA USA', u'USA, USA', u'California',
#        u'Los Osos, CA', u'Berkeley, CA', u'West of Oz', u'Charlotte',
#        u'New York, NY', u'SFO', u'Oakland, California', u'Oakland, CA',
#        u'Lower Haight, San Francisco', u'California, USA',
#        u'San Francisco via Adelaide', u'Santa Monica, CA',
#        u'Redding, Calif.', u'Washington, DC', u'Utah',
#        u'State College, PA', u'Vancouver', u'DC', u'Sacramento, CA',
#        u'\xdcT: 41.991823,-70.716601', u'Oakland & California',
#        u'Seattle, WA', u'Orange County, CA', u'pacific rim',
#        u'Portland, OR', u'Oakland, California; Toronto; Portland; global',
#        u'Austin, TX', u'Raleigh, NC', u'Rockbridge Baths, VA',
#        u'Manassas, VA', u'DC via Lancaster, PA', u'Alameda, CA',
#        u'New Brunswick, NJ', u'Melbourne, VIC, Australia',
#        u'Livermore, CA', u'west phila best phila', u'fremont, seattle',
#        u'Buffalo, NY', u'Vancouver,B.C.', u'St. Louis, MO- south city',
#        u'Knoxville Tennessee', u'Montclair, NJ', u'Palo Alto, CA',
#        u'Columbus, OH', u'Oakland CA', u'Philly - San Francisco, CA',
#        u'Berkeley.', u'LA, Gual\xe1n, Hamburg', u'Pleasanton, CA',
#        u'Marinwood, CA', u'Skagit, Washington State, USA',
#        u'West Valley, Silicon Valley CA', u'The Numbers, Portland, OR',
#        u'San Rafael', u'San Jose, CA', u'San Leandro, CA',
#        u'Gluten\u2019s Heart of Darkness', u'CALIFORNIA ~ South & North  ',
#        u'Miami, SF & Global', u'San Francisco & Global', u'Barstow, CA',
#        u'San Francisco via ATL and NC', u'#thistown',
#        u'Occupied Ohlone territory', u'Roxbury, Boston', u'Bay area, CA',
#        u'California Republic', u'Seattle, WA, USA', u'Lafayette, CA',
#        u'Silicon Valley | SF | 39.5K Ft',
#        u'Easy to find, hard to predict.', u'Dallas, TX', u'America',
#        u'Santa Clara, CA', u'France', u'San Francisco Ca', u' USA',
#        u'Toronto, Canada', u'Spuyten Duyvil, Bronx', u"St. John's, Canada",
#        u'Incomplete Streets, CA', u'Durham, NC, USA', u'SF Bay Area',
#        u'San Francisco, California', u'Sunnyvale, CA', u'Berkeley CA',
#        u'depends on momentum', u'Sodom-on-the-Bay, California',
#        u'Maplewood, NJ', u'Deep State, NJ ', u'he/him', u'San Carlos, CA',
#        u'Berkeley, California', u'Mid-City West, Los Angeles',
#        u'Los Angeles, CA, USA', u'Frankfurt, Germany',
#        u'https://youtube.com/invisiblepeople',
#        u'San Diego, CA \u2022 he/him/his', u'Woodside, CA',
#        u'berkeley, ca', u'Irving, Texas', u'San Francisco, CA ',
#        u'Salinas, CA', u'Portland, Oregon',
#        u'Leimert Park, Los Angeles, CA', u'SoMa, San Francisco',
#        u'SF, Silicon Valley and beyond', u'Denver, CO',
#        u'Mississippi, USA', u'Guinea Bissau', u'Monterey County',
#        u'Glendale, California', u'Pendleton, OR', u'SoCal',
#        u'San Francisco Bay Area', u'Charlotte, NC', u'Durham, NC',
#        u'Olympic Tower', u'Muncie, IN', u'Texas, USA',
#        u'San Mateo County, Calif.', u'DC via Appalachia',
#        u'Ireland, Lebanon, Palestine', u'West Hollywood, CA',
#        u'cyberspace', u'Ajax. Ontario Canada', u'Boston, MA',
#        u'santa cruz, ca', u'Van Nuys, CA', u'Northern California',
#        u'san francisco | sacramento', u'Ventura, CA',
#        u'DC by way of Upstate NY', u'Atlanta, GA',
#        u'Grant Road Sylvan Park Area, Mountain View', u'Santa Cruz, CA',
#        u'Toronto, Ontario', u'Silicon Valley', u'New York',
#        u'Houston, Texas', u'Oakland', u'Colombia', u'Chicago, IL',
#        u'Long Beach, CA', u'Oakland, CA and Portland, OR',
#        u'South Pasadena, CA', u'Cupertino, California',
#        u'Rhode Island, USA', u'LA, CA', u'510', u'Olathe, KS',
#        u'Seattle, Washington, USA', u'Davos, Switzerland', u'Irvine, CA',
#        u'New York | Boston', u'Usually Malaysia or the US',
#        u'San Diego, California', u'SF', u'San Francisco, ca',
#        u'Brooklyn NY', u'upstate New York', u'Glendale', u'El Cerrito, CA',
#        u'Toronto', u'Newark, NJ', u'Longview, TX',
#        u'South Florida, U.S.A.', u'South Carolina, USA',
#        u'Bedford Hills, NY', u'USA', u'Santa Cruz County CA', u'Purgatory',
#        u'Houston, TX', u'Santa Barbara', u'Greater Seattle area',
#        u'SF Bay Peninsula', u'Chicago / NYC / High Point', u'Moon',
#        u'Bay Area', u'Richmond, CA', u'San Francisco CA',
#        u'Menlo Park, CA', u'Earth', u'fishin 4 good perch',
#        u'San Francisco, Silicon Valley', u'Charlottesville, VA', u'Italy',
#        u'LA via NY via SP via SF', u'Seattle', u'LA LA Land',
#        u'UC Berkeley', u'SF, CA', u'Ca, Co, NY, Fl, Ak, USA',
#        u'SF,CA + PDX,Cascadia', u'Arlington, MA', u'Detroit suburbs',
#        u'Bay Area, CA', u'iPhone: 39.905247,-86.219940', u'Minnesota, USA',
#        u'Stanford, CA', u'Sausalito, CA', u'Los Altos, CA',
#        u'South Los Angeles', u'Charlottesville, VA, USA', u'Davis, CA',
#        u'San Francisco\u2022Oakland\u2022San Jose', u'Larkspur, CA, USA',
#        u'The Based North', u'ABQ NM', u'Venice, CA',
#        u'San Leandro and Oakland, CA', u'West Coast USA',
#        u'Outer Sunset, San Francisco', u'Cole Valley, San Francisco',
#        u'El Portal', u'Minneapolis, MN', u'Toronto, Ontario, Canada',
#        u'\u2665 \u262f \u2665', u'NY/NJ', u'Idaho, USA',
#        u'near the shellmound', u'Metairie, LA',
#        u'wandering the 3rd dimension', u"Banker's Hill, San Diego",
#        u'West Coast', u'Body: DC. Soul: Boston.', u'Rocklin, CA',
#        u'Woodley Park, DC', u'union. somerville. ma. usa.',
#        u'Bandis.Stockholm.se', u'Cambridge, MA', u'berlin | the future',
#        u'Somewhere', u'Everywhere', u'Helsinki, Suomi', u'Olympia, WA',
#        u'Global', u'Somerville/S\xe3o Paulo/Joburg', u'NYC, RDU, AXA, ANU',
#        u'Mostly Berlin', u'London | Birmingham', u'Bangalore, India',
#        u'Dublin, Ireland and California', u'Vilnius', u'Boulder, CO',
#        u'Mountain View, CA, US', u'Englewood, CO',
#        u'\xdcT: 37.603539,-122.385962', u'Bakersfield, California',
#        u'Canada, India, USA', u'Somewhere in hell. ',
#        u'34.020623,-118.289693', u'Diamond Heights, San Francisco',
#        u' Toronto and Vancouver', u'Los Angeles, California',
#        u'United States', u'Ohlone Land', u'Greater Midwest',
#        u'minneapolis, mn', u'CA 49', u'Sierras & Half Moon Bay CA',
#        u'37.472088,-122.221390', u'New York City', u'West Hartford, CT',
#        u'Bay Area, California', u'DTLA', u'New Haven, CT', u'Redmond, WA',
#        u"Bay Area's Black Wall Street",
#        u'Minneapolis, colonized Dakota land', u'Huntington Beach, CA',
#        u'San Francisco and Oakland, CA', u'Parts unknown', u'Oxnard CA ',
#        u'chicago', u'Belmont Shore (Long Beach) CA', u'Richmond, VA',
#        u'Join the movement!', u'El Cerrito, California', u'Fresno',
#        u'Wall Street', u'Based in Los Angeles', u'Sacramento',
#        u'Austin, TX via Nawf Dallas, TX', u'Wisconsin, USA',
#        u'NC \u27a1\ufe0f CA', u'Fern Street, San Francisco',
#        u'Kansas, USA', u'los angeles ca', u'downtown San Jose, CA',
#        u'Sh\xef\u03c4cr\xe4terstania', u'NYC', u'Various',
#        u'District of Columbia, USA', u'Rockville, MD',
#        u'PGP: http://bit.ly/1Nja4jP', u'London', u'Cambridge, England',
#        u'Mile High, CO', u'Southeast U.S.', u'Texas',
#        u'SF Bay Area Peninsula', u'Riyadh', u'United States of America',
#        u'New York, New York', u'San Francisco, CA, USA',
#        u'San Francisco, California, USA', u'Twin Cities, Minnesota',
#        u'Auburn, AL', u'Salt Lake City, Utah',
#        u'chicago \U0001f315 palo alto', u'Bump City, CA', u'Greenwich, UK',
#        u'Barrio Echo Parque, Alta Calif', u'Cleveland', u'EARTH ',
#        u'occupied Ohlone land', u'Pomona, California',
#        u'Muwekma Ohlone Land', u'La Lengua, SF', u'Philadelphia, PA',
#        u'Glendale, CA', u'San Francisco, CA (Occupied Ohlone Land)',
#        u'Springfield, MA', u'Pasadena, CA', u'Bremerton WA',
#        u'On the beach playing volleyball', u'CA', u'san diego, ca',
#        u'Adult Neurology', u'Redwood City, CA | Los Angeles',
#        u'Ohlone land (University Ave)', u'Union, NJ', u'Somerville, MA',
#        u'Boshwash Megalolpolis', u'San Francisco Teocuitlatepec, CA',
#        u'Northridge, California', u'South San Francisco, CA',
#        u'san francisco, ca', u'San Francisco, Caliornia USA',
#        u'Guadalajara, Jalisco', u'Cambridge MA', u'Anaheim, CA',
#        u'Trump Train Station', u'Marin County, California',
#        u'Savannah, GA', u'St Petersburg, FL', u'Orange County, California',
#        u'New York, USA', u'Phoenix, AZ',
#        u'CaliforNoThankYou\u270b\U0001f3fd', u'Portland, OR USA',
#        u'Nomidlats', u'Omaha, NE', u'DC USA', u'new york',
#        u'Berkeley, California, USA', u'New World Order',
#        u'my old oakland home', u'Brooklyn', u'northern CA', u'Belmont, CA',
#        u' Los Angeles ', u'SF Bay Area, CA', u'Boston', u'Sac-Toe CA',
#        u'Rohnert Park, CA', u'Manhattan/NYC', u'Denton, TX', u'WA',
#        u'Brooklyn, NY//Oakland, CA', u'Pacifica, CA',
#        u'San Francisco Bay Area, CA', u'Chicago ex-pat in Los Angeles',
#        u'San Jose', u'90065', u'iPhone: 35.912838,-79.048080',
#        u'where the Tweets flow', u'Lancaster, PA', u'Planet Earth',
#        u'earth', u'san francisco', u'Buenos Aires, Argentina',
#        u'Santa Clara County, CA', u'Southern California', u'Buenos Aires',
#        u'North Carolina, USA', u'San Francisco, North America',
#        u'Burbank, CA', u'Montague, Massachusetts', u'Washington DC',
#        u'Forest Hill Hex', u'Porto Alegre, Brazil', u'Indianapolis, IN',
#        u'London, England', u'Puget Sound, WA', u'Oregon, USA',
#        u'Normal, IL', u'SF, CA 94116', u'from Cleveland, in Oakland',
#        u'los angeles', u'Dublin City, Ireland', u'Houston', u'mourning',
#        u'Contra Costa County, CA', u'Tokyo', u'Norwich',
#        u'National City, CA', u'Dorset', u'South London',
#        u'Los Angeles, CA 91601', u'Bloom 4 Assembly FPPC#1392468',
#        u'Australia', u'College Park, MD', u'Flagstaff, AZ',
#        u'Portland, OR Metopolitan Area', u'NORCAL', u'Oakland, CA, USA ',
#        u'The HIVEMIND, RNC HQ', u'Khar, Bajaur Agency', u'Studio City, CA',
#        u'Berkeley', u'san diego ', u'Albuquerque, NM',
#        u'SFO (via EWR - BIO - DCA)', u'sutherland Shire',
#        u'Greater Vancouver', u'Kirkland WA', u'Multnomah land ',
#        u'm@mschade.me \xb7 San Francisco', u'Fairfield, CA',
#        u'Born to Lose, Live to Win', u'Redondo Beach, CA',
#        u'SoCal/St. Louis', u'DC, Chicago, SF, NYC',
#        u'Between the bid and the ask', u'La Misi\xf3n, San Francisco',
#        u'Rosemead, CA', u'Redondo Beach', u'The Dance Archipelago',
#        u'Out of this world\xbbSFC  ', u'The Haight, San Francisco',
#        u'Elysian Valley, Los Angeles', u'Los Angeles- Boston ',
#        u'South San Francisco, CA, USA', u'Vancouver - LA',
#        u'Agoura Hills, CA', u'Bernal Heights', u'Daly City, CA',
#        u'Fresno, CA', u'iPhone: 49.284729,-123.109573', u'Union City, CA',
#        u'Fremont, CA', u'Placerville, CA', u'Van Nuys, Los Angeles',
#        u'Rialto, CA', u'Oakland, Ca', u'Mountain View, CA',
#        u'San Francisco CA & Naoned BZH', u'Manhattan, NYC',
#        u'Homey Nation of KSPB', u'Minneapolis',
#        u'My company is @CreativeSage', u'Eugene, OR', u'SF Bay Area, USA',
#        u'Port Harcourt, Nigeria', u'Oaktown by the Lake',
#        u'San Francisco, CA \U0001f1fa\U0001f1f8', u'Seattle\n',
#        u'San Francisco & Davis, CA', u'Oaklandish', u'San Ramon, CA',
#        u'North America', u'Fairfax County, VA', u'Manhattan',
#        u'Washington DC, United States', u'\u2736\u2736\u2736\u2736, il',
#        u'Northern California ', u'Rose Hill, New York, NY', u'Memphis, TN',
#        u'New York,New York', u'Wakefield, MA', u'Iowa City, Iowa',
#        u'Front Range, CO', u'South Central Los Angeles',
#        u'Monterrey, Nuevo Le\xf3n', u'So Cal', u'Washington, DC, USA',
#        u'Chicago/LaGrange/Itasca, IL', u'St. Petersburg, FL', u'Calgary',
#        u'Napa, CA', u'North Carolina', u'Chicago Botanic Garden',
#        u'At sea on the Hansa Freyburg', u'Brooklyn and Queens',
#        u'BUF \u27a1\ufe0f LA', u'San Francisco Mission District',
#        u'Ambivalent Angelenx', u'Stolen Tongva Land',
#        u'San Jose, Calif. USA', u'Los Angeles Metro Area',
#        u'Socialist hellscape', u'Tampa, FL', u'\u2708\ufe0f',
#        u'Emeryville, CA', u'Chico, CA', u'Nowhere, especially not LA',
#        u'Silver Spring, MD', u'3rd planet in minor solar sys',
#        u'Modesto, CA', u'Holyoke, MA', u'Bethlehem, Pennsylvania',
#        u'Decatur, GA', u'Orlando, FL', u'East Coast! Fuck You!',
#        u'Westwood, Los Angeles', u'Mill Valley, CA', u'Atlanta',
#        u'Manhattan, NY', u'Sucka Free City', u'Healdsburg, CA',
#        u'In the desert.', u'Ottawa, Canada', u'The Excelsior',
#        u'Oakland, Calif', u'OR/CA/DC/NY', u'SF, CA via South Dakota',
#        u'Newport Beach, CA', u'john.myers@latimes.com', u'Dathomir',
#        u'Rhode Island', u'San Francisco, The Internet',
#        u'South LA, Boyle Hts, & beyond', u'Redwood City, CA',
#        u'World Citizen', u'Excelsior, San Francisco ', u'Canada',
#        u'The Ancient Shore of Laurentia', u'Walnut Creek, CA',
#        u'Providence, RI', u'Harvard University', u'pond',
#        u'Sydney, Australia', u'Azusa Tar Pits',
#        u'Minnesota | Austin, Texas', u'central Florida',
#        u'republic of the spirit', u'Boyle Heights, California',
#        u'Vancouver, BC', u'boston ish', u'Prob somewhere watching Logan',
#        u'Oakton, Virginia', u'LA \u2708\ufe0f NYC \u2708\ufe0f SF',
#        u'San Francisco, CA, US', u'Newton, MA', u'Ray Romano, Ray Romano',
#        u'Innisfil , ON', u'San Francisco - Bay Area',
#        u'The Space Force Core', u'Dorchester, MA', u'NW LDN',
#        u'Paris, France', u'Wherever permits can be pulled',
#        u'Lafayette, IN', u'Newark/NOLA',
#        u'Fake, non rural America. City of Roses, OR.',
#        u'Kawasaki-shi Miyamae, Kanagawa', u'Sacramento, Reno & Tahoe',
#        u'Tenderloin, San Francisco', u'Body: SF, Spirit Animal: CO',
#        u'PDX, DC, NC', u'Pittsburgh, PA', u'La Mesa, CA',
#        u'Silicon Valley, CA', u'China', u'SF, ATX, SATX', u'Bronx, NY',
#        u'Irvine', u'Vancouver, BC, Canada', u'Indianapolis',
#        u'Wakanda by way of  Belize ', u'Alexandria, VA', u'washington dc',
#        u'Vancouver, British Columbia', u'DC Suburbs', u'Costa Mesa, CA',
#        u'\xdcT: 34.041042,-118.191894', u'Seaside, California, USA',
#        u'Dogpatch, San Francisco', u'Berkeley, CA, 1970',
#        u'Summerside, PE, Canada', u'Chicago', u'Fullerton, CA',
#        u'Lincoln Heights, CA', u'L.A.via WashHts/HarlemNYC',
#        u'Alameda, CA and Sonora, CA', u'\u2514A', u'Vancouver, Canada',
#        u'Gay space communist colony', u'Brea, CA',
#        u'New York City & Southeastern CT', u'901 Monroe Adjacent',
#        u'San Francisco Chronicle', u'Cambridge, Mass.', u'South Bay. SF.',
#        u'Providence',
#        u'Brooklyn West. Less public transit, but better tacos.',
#        u'\xdcT: 37.770364,-122.410351', u'los angeles, ca',
#        u'Honolulu/No. Cal.', u'Inner Sunset, San Francisco',
#        u'Los Angeles, California, USA', u'Sacramento,CA (City of Dreams)',
#        u'Iowa City, IA', u'Sacramento, CA ', u'Oakland, CA and beyond',
#        u'100% DEATH TAX', u'SF Bay Area, California', u'Bradenton, FL',
#        u'SF | LA | NY | CHI | Paris', u'Boulder, Colorado, USA'], dtype=object)

# %% [markdown]
# Save the dataframe before progressing

# %%
dffile = 'SB827df.pkl'
SBdf.to_pickle(dffile)

# %% [markdown]
# ## Label The Tweets
#
# In order to start classifying the tweets, it is first necessary to label a bunch of them as being in favor of, in opposition to, or neutral to the bill. It is assumed in this labeling process that retweets of tweets from known supporters or people from the opposition, even when the wording of the tweet itself is neutral, is associated with the position of the person being retweeted.

# %%
#randomize the order of the tweets
SBdf = SBdf.sample(frac=1).reset_index(drop=True)

# %%
dffile = 'SB827df_2.pkl'
SBdf = pd.read_pickle(dffile)

# %%
print SBdf.shape
num_tweets = SBdf.shape[0]
Approves = np.zeros((num_tweets,1))
# Out:
# (3378, 5)

# %%
#Split off a block of tweets to label
Train = SBdf.text[0:num_tweets*3//10-1]

# %%
def label_maker(tweetlist):
    tweetlist = tweetlist.reset_index()
    tot_tweet = tweetlist.shape[0]
    concur = np.zeros((tot_tweet,1))
    for i in range(0,tot_tweet):
        print tweetlist.loc[i].text
        concur[i]=input("Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral")
    return concur

# %%
#Label a chunk of the tweets. Initially I intended to label all of the tweets in this set,
#but it turns out that labeling hundreds of tweets is, in fact, time consuming.
#So I settled for only labeling 300 tweets.

Train_approve = np.zeros([Train.shape[0],1])
Train_approve[0:5]=label_maker(Train[0:5])
# Out:
# Absolutely. And for all the fighting in SF, the campaign to pass #SB827 was lost in #LosAngeles as I describe in my… https://t.co/JrHEyYJlnl
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral0
# RT @Tracktwentynine: Is it sad that the most transformative housing bill in the country died tonight, the first time anything like it was p…
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 allows “unlimited luxury condo high rises.” That’s false (it’s 4-5 story buildings) &amp; an odd c…
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# #Cities, if you were really upset about what #SB827 was going to do to your local community, now is your chance. Pa… https://t.co/D54J0f9Rcd
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# Housing Is A Human Right &amp; many other housing justice and tenants groups successfully fought to defeat the pro-gent… https://t.co/8N7gItB41o
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral0

# %%
np.save('Train_approve.npy',Train_approve) #Saved the labels

# %%
#Save the tweets in the order that's associated with the labels
dffile = 'SB827df_2.pkl'
SBdf.to_pickle(dffile)

# %%
Train_approve[295:300]=label_maker(Train[295:300])
# Out:
# RT @dillonliam: As GOP Sen. @TedGaines speaks in support, it’s also remarkable that there appears there could be more Republican support fo…
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# RT @dillonliam: It’s officially dead #SB827. Four votes in favor.
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# After co-author Nancy Skinner speaks in favor of #sb827 Sen McGuire, chair of the next committee to which the bill… https://t.co/PdtDEbSJYx
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral2
# #SB827 😢😥😓
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1
# RT @drvox: #SB827 has died in committee because everyone sucks &amp; everyone prefers the horrific, unsustainable, unjust status quo to a solut…
# Does this tweet approve of SB827? 0 for no, 1 for yes, 2 for neutral1

# %% [markdown]
# # Train a Classifier
#
# Now we're going to break the labeled tweets into Training, Cross Validation, and Test Sets in order to attempt to train some classifiers on them.

# %%
dffile = 'SB827df_2.pkl'
SBdf = pd.read_pickle(dffile) #Load dataframe created in prior section

# %%
Train_approve = np.load('Train_approve.npy') #Load labels created in prior section

# %%
SBdf
# Out:
#      followers_count                             location      screen_name  \
# 0               2989                    San Francisco, CA      beyondchron
# 1               2356                 Salt Lake City, Utah          MRC_SLC
# 2               1197                    San Francisco, CA    marcus_ismael
# 3                510                      Los Angeles, CA          Asmarcd
# 4                661                      California, USA   HousingHumanRt
# 5                797                        San Diego, CA      msmayarosas
# 6               1201        South LA, Boyle Hts, & beyond    sahrasulaiman
# 7               3797                        San Francisco         sutrofog
# 8               1677                     sutherland Shire  donaldh66287394
# 9                911                       Washington, DC   vanessabcalder
# 10             11869                       Sacramento, CA       dillonliam
# 11              4709                         Berkeley, CA         mateosfo
# 12               110                            BUF ➡️ LA   darryl_granger
# 13               494                          Oakland, CA     KyleAPennell
# 14               538                        San Francisco           torque
# 15              3287                 The Space Force Core    nyc_data_geek
# 16              2480           from Cleveland, in Oakland       dsmpowered
# 17               322                              Atlanta        TroyWhyte
# 18               695                           LA LA Land      melyssablue
# 19               425                              Vilnius          mgedmin
# 20              1629                  Bandis.Stockholm.se           GuSv01
# 21              4405            ÜT: 34.041042,-118.191894      kmontenegro
# 22               150                                              kdhively
# 23             33090                        San Francisco  SFBusinessTimes
# 24              3785                         Brooklyn, NY             mtsw
# 25                82                                              jcubsden
# 26              5486            L.A.via WashHts/HarlemNYC       tanlogadas
# 27             46886            San Francisco, California     Scott_Wiener
# 28               449                      Los Angeles, CA       cshepherds
# 29               483                        Mile High, CO     namhenderson
# ...              ...                                  ...              ...
# 3348              62                                       freddynietzschy
# 3349           27076  https://youtube.com/invisiblepeople     hardlynormal
# 3350              18                      Forest Hill Hex    ForestHillExt
# 3351              24                                       constituents381
# 3352             277                Van Nuys, Los Angeles     VoteForRoger
# 3353             153                         Berkeley, CA       mrlewis125
# 3354             365                          Los Angeles       jacobwooch
# 3355              12                             USA, USA   EpiphyteCities
# 3356              58                      Los Angeles, CA    DaShoeMonstar
# 3357            1370                   San Francisco, CA      marymcnamara
# 3358             431                    San Francisco, CA       irishbryan
# 3359            5238                        San Diego, CA  LisaHalverstadt
# 3360            7928                           Sacramento  MelodyGutierrez
# 3361             981                                          TaupeAvenger
# 3362              33                                          CAACentralCA
# 3363            1007                          Los Angeles       DuboffJess
# 3364            2936                    San Francisco, CA            SFHAC
# 3365             521                                            aceckhouse
# 3366            2168                          Oakland, CA   CitizenCassidy
# 3367             342                      Los Angeles, CA      nbousfield_
# 3368            1370                   San Francisco, CA      marymcnamara
# 3369            4739                       Sacramento, CA         Calefati
# 3370             227                    San Francisco, ca           donjay
# 3371            1597                      Los Angeles, CA       CleftClips
# 3372            1757                                          Saferhermosa
# 3373            2936                    San Francisco, CA            SFHAC
# 3374              11                                            JamesAria1
# 3375             340                        San Francisco        gillibits
# 3376            1195                     Toronto, Ontario  VoteTimGrantGPO
# 3377             243        Portland, OR Metopolitan Area         BranBrez
#
#                                                    text  \
# 0     Absolutely. And for all the fighting in SF, th...
# 1     RT @Tracktwentynine: Is it sad that the most t...
# 2     RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 a...
# 3     #Cities, if you were really upset about what #...
# 4     Housing Is A Human Right &amp; many other hous...
# 5     RT @cayimby: Profound thanks to Sen. @Scott_Wi...
# 6     RT @dillonliam: It’s officially dead #SB827. F...
# 7     RT @mikevladimer: @MarkLeno @AaronPeskin I gre...
# 8     RT @AlexSteffen: The single most powerful solu...
# 9     "The larger issue is that too many Democrats h...
# 10    One Senator speaking, one Senator opposed. Dem...
# 11    RT @michaeldlane: Boom!💥 Real progressives wo...
# 12    RT @cayimby: Your urgent advocacy for #SB827 m...
# 13                                #SB827 is dead. Dang.
# 14    RT @Scott_Wiener: 3/4 Angela Alioto is a good ...
# 15    RT @AlexSteffen: The early defeat of #SB827, C...
# 16    RT @damienISgoodmon: If a Senator w/a history ...
# 17    RT @byJoshuaDavis: Some white politicians are ...
# 18    RT @cayimby: “Legislator after legislator talk...
# 19    RT @uhshanti: I'm just hashtagging #SB827 so p...
# 20    RT @schmangee: I wonder if the Federal Transit...
# 21    RT @TenantsTogether: Anya at @Western_Center: ...
# 22    RT @theoverheadwire: This is the building that...
# 23    .@Scott_Wiener's housing-transit measure #SB82...
# 24    RT @SFyimby: Legislators seem to be letting th...
# 25    RT @justupthepike: #SB827 is already changing ...
# 26    RT @turbolars: to anyone in the #SanFrancisco ...
# 27    The @latimes opposed #SB827 because it actuall...
# 28    RT @EthanElkind: When #SB827 came out, I was a...
# 29    RT @ariellesallai: Thank fuck #SB827 is dead a...
# ...                                                 ...
# 3348  But then our body, as a saint in the backgroun...
# 3349  RT @rbramson: I feel like with the recent demi...
# 3350  RT @Scott_Wiener: Today #SB827 did not advance...
# 3351  @kimmaicutler CA needs to stop giving into the...
# 3352  RT @HousingHumanRt: And it's dead! Scott Wiene...
# 3353  RT @HousingHumanRt: And finally @BenAllenCA gi...
# 3354  RT @damienISgoodmon: The only votes sponsors @...
# 3355  RT @graue: If you support housing and transit ...
# 3356  RT @cayimby: Legislator after legislator talke...
# 3357  RT @jillstewart: Scott Wiener just praised his...
# 3358  RT @Scott_Wiener: 1/4 Leadership starts with b...
# 3359  RT @dillonliam: My first take on the demise of...
# 3360  .@Scott_Wiener now here and is about to take u...
# 3361  RT @aceckhouse: This bill is controversial bec...
# 3362  @Scott_Wiener @NeverSassyLaura. @yimbyaction\n...
# 3363  Reference to Rubio #CEQA bill by @TedGaines .....
# 3364  RT @HousingTrustSV: https://t.co/bZKLOrXai4 Th...
# 3365  lol Senator Beall is not pleased about Vice-Ma...
# 3366  RT @JerryJonesICLC: California's #SB827 is dea...
# 3367  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3368  RT @dillonliam: You may have heard that the co...
# 3369  Just walked into the @CALmatters office at 8:2...
# 3370  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3371  RT @ramez: I 100% agree with Alex. #SB827 was ...
# 3372  RT @Scott_Wiener: “We can have all the electri...
# 3373  RT @dillonliam: 🎉It’s #SB827 day🎉 A thread t...
# 3374  RT @jillstewart: Scott Wiener bill #SB827 defe...
# 3375  RT @IanCarlton: CA's #SB827 could have increas...
# 3376  RT @salimfurth: .@mattyglesias, @ebwhamilton a...
# 3377  RT @Scott_Wiener: Today #SB827 did not advance...
#
#                         time_zone
# 0      Pacific Time (US & Canada)
# 1     Mountain Time (US & Canada)
# 2      Pacific Time (US & Canada)
# 3      Pacific Time (US & Canada)
# 4                            None
# 5                            None
# 6                         Arizona
# 7      Pacific Time (US & Canada)
# 8                            None
# 9                            None
# 10     Pacific Time (US & Canada)
# 11     Pacific Time (US & Canada)
# 12     Pacific Time (US & Canada)
# 13                        Arizona
# 14     Pacific Time (US & Canada)
# 15                           None
# 16     Eastern Time (US & Canada)
# 17                     Georgetown
# 18     Pacific Time (US & Canada)
# 19                        Vilnius
# 20                      Stockholm
# 21     Pacific Time (US & Canada)
# 22                           None
# 23     Pacific Time (US & Canada)
# 24     Eastern Time (US & Canada)
# 25                           None
# 26                           None
# 27     Pacific Time (US & Canada)
# 28                         Alaska
# 29    Mountain Time (US & Canada)
# ...                           ...
# 3348                         None
# 3349                Europe/London
# 3350                         None
# 3351                         None
# 3352                         None
# 3353                         None
# 3354                         None
# 3355                         None
# 3356                         None
# 3357   Pacific Time (US & Canada)
# 3358   Eastern Time (US & Canada)
# 3359   Pacific Time (US & Canada)
# 3360                       Alaska
# 3361   Pacific Time (US & Canada)
# 3362                         None
# 3363   Pacific Time (US & Canada)
# 3364   Pacific Time (US & Canada)
# 3365                         None
# 3366   Pacific Time (US & Canada)
# 3367   Pacific Time (US & Canada)
# 3368   Pacific Time (US & Canada)
# 3369   Pacific Time (US & Canada)
# 3370   Pacific Time (US & Canada)
# 3371          America/Los_Angeles
# 3372          America/Los_Angeles
# 3373   Pacific Time (US & Canada)
# 3374                         None
# 3375   Pacific Time (US & Canada)
# 3376   Eastern Time (US & Canada)
# 3377   Pacific Time (US & Canada)
#
# [3378 rows x 5 columns]

# %%
#Split text of labeled tweets into training, cross validation, and test sets
Train = SBdf.text[0:200]
CrossVal = SBdf.text[200:260]
Test = SBdf.text[260:300]
Other = SBdf.text[300:SBdf.shape[0]]

# %%
#Split labels into training, cross validation, and test sets
Train_Label = Train_approve[0:200]
CrossVal_Label = Train_approve[200:260]
Test_Label = Train_approve[260:300]

# %%
#First let's clean up the text further and get rid of special characters
def clean_up_text(df):
    df = df.str.replace(r"http\S+", "")
    df = df.str.replace(r"http", "")
    df = df.str.replace(r"@\S+", "")
    df = df.str.replace(r"[^A-Za-z0-9(),!?@\'\`\"\_\n]", " ")
    df = df.str.replace(r"@", "at")
    df = df.str.lower()
    return df

# %%
def format_for_textblob(Tweets, Labels, fname):
    Tweets = Tweets.reset_index(drop=True)
    Tweets = clean_up_text(Tweets)
    tot_tweets = Tweets.shape[0]
    tot_label = Labels.shape[0]
    if tot_tweets==tot_label:
        with open(fname,'wv') as csvf:
            tweetwriter = csv.writer(csvf)
            for i in range(tot_tweets):
                if Labels[i]==1:
                    label = 'pos'
                else:
                    label = 'neg'
                tweet = Tweets.loc[i]
                new_tweet = str(tweet.encode('utf-8')) #this will deal with any remain weird characters
                tweetwriter.writerow([new_tweet, label])
        print ("Saved file")
    else:
        print "Bad News: Lists weren't of the same size"

# %%
format_for_textblob(Train, Train_Label, 'train_with_labels.csv')
# Out:
# Saved file

# %%
format_for_textblob(CrossVal, CrossVal_Label, 'crossval_with_labels.csv')
# Out:
# Saved file

# %% [markdown]
# A Naive Bayes Classifier is going to be training on the labeled data and used to predict labels for the rest of the tweets. This type of classifier is really basic and easy to interpret. It assumes no dependence between the features (in this case, words) and try to predict the probability that a tweets is in the positive or negative cases based purely on the frequency of the words contained within. It's simplicity and interpretability makes it a good first model. The implementation through textblob conveniently requires minimal preprocessing.

# %%
from textblob.classifiers import NaiveBayesClassifier

# %%
with open('train_with_labels.csv','r') as fp:
    cl = NaiveBayesClassifier(fp, format='csv')

# %%
with open('crossval_with_labels.csv','r') as cross:
    print cl.accuracy(cross, format ='csv')
# Out:
# 0.733333333333

# %%
cl.show_informative_features(20)
# Out:
# Most Informative Features
#            contains(one) = True              neg : pos    =      6.6 : 1.0
#        contains(against) = True              neg : pos    =      5.8 : 1.0
#          contains(about) = True              pos : neg    =      5.4 : 1.0
#          contains(voted) = True              pos : neg    =      5.0 : 1.0
#            contains(sen) = True              neg : pos    =      5.0 : 1.0
#           contains(says) = True              neg : pos    =      4.5 : 1.0
#            contains(san) = True              neg : pos    =      4.5 : 1.0
#       contains(building) = True              neg : pos    =      4.5 : 1.0
#      contains(francisco) = True              neg : pos    =      4.5 : 1.0
#          contains(bills) = True              neg : pos    =      4.5 : 1.0
#            contains(pro) = True              neg : pos    =      4.5 : 1.0
#            contains(out) = True              pos : neg    =      4.5 : 1.0
#             contains(at) = True              neg : pos    =      4.2 : 1.0
#             contains(no) = True              neg : pos    =      4.2 : 1.0
#          contains(votes) = True              neg : pos    =      4.2 : 1.0
#          contains(going) = True              neg : pos    =      4.1 : 1.0
#            contains(not) = True              pos : neg    =      4.1 : 1.0
#             contains(my) = True              pos : neg    =      3.6 : 1.0
#           contains(near) = True              pos : neg    =      3.6 : 1.0
#            contains(new) = True              neg : pos    =      3.5 : 1.0

# %%
def confusion_matrix_stats(Tweets, labels, cla):
    from textblob import TextBlob
    Tweets = Tweets.reset_index(drop=True)
    Tweets = clean_up_text(Tweets)
    tot_tweets = Tweets.shape[0]
    true_pos = 0
    false_pos = 0
    true_neg = 0
    false_neg = 0
    for i in range(tot_tweets):
        tweet = Tweets.loc[i]
        label = labels[i]
        new_tweet = str(tweet.encode('utf-8'))
        blob_tweet = TextBlob(new_tweet, classifier = cla)
        blob_label = blob_tweet.classify()
        if blob_label =='pos':
            if label == 1:
                true_pos += 1
            else:
                false_pos += 1
        elif label ==1:
            false_neg += 1
        else:
            true_neg += 1
    return (true_pos, false_pos, true_neg, false_neg)

# %%
(tp, fp, tn, fn) = confusion_matrix_stats(CrossVal, CrossVal_Label, cl)
print tp
print fp
print tn
print fn
# Out:
# 36
# 13
# 8
# 3

# %% [markdown]
# So that's a modest first attempt. The classifier has okay accuracy and deals fairly well with how inbalanced the classes are, but based on the informative features list it and overrates innocuous pieces of information. Additionally, due to the larger number of false positives than false negatives, it is worth noting that this classifier will likely overstate the amount of support for SB 827.
#
# I also tried some of the other classifiers within the TextBlob package (such as the Decision Tree Classifier below) but ultimately these didn't seems to perform any better.

# %%
from textblob.classifiers import DecisionTreeClassifier
with open('train_with_labels.csv','r') as fp:
    treecl = DecisionTreeClassifier(fp, format='csv')

# %%
with open('crossval_with_labels.csv','r') as cross:
    print treecl.accuracy(cross, format='csv')
# Out:
# 0.683333333333

# %%
(tp, fp, tn, fn) = confusion_matrix_stats(CrossVal, CrossVal_Label, treecl)
print tp
print fp
print tn
print fn
# Out:
# 34
# 14
# 7
# 5

# %% [markdown]
# With more time it could have been useful to use Word2Vec to get a semantic embedding of the tweets and then train a classifier (with the assistance of the Scikit-learn package) from there, but I stuck with the textblob Naive Bayes Classifier for the purposes of this project. After all, I'm just trying to get a vague gauge of the popularity of a dead senate bill. This isn't a model that will be pushed out to a broader use case.

# %% [markdown]
# # Classify and Analyze
#
# Now that there's a trained classifier it will be used to classify the other tweets and then doing some very basic analysis of the levels of support for the bill.

# %%
def classify_other_tweets(Tweets, cla):
    from textblob import TextBlob
    Tweets = Tweets.reset_index(drop=True)
    tot_tweets = Tweets.shape[0]
    labels = np.zeros([tot_tweets,1])
    for i in range(tot_tweets):
        tweet = Tweets.loc[i]
        new_tweet = str(tweet.encode('utf-8'))
        blob_tweet = TextBlob(new_tweet, classifier = cla)
        blob_label = blob_tweet.classify()
        if blob_label =='pos':
             num_label = 1
        else:
             num_label = 0
        labels[i]=num_label
    return labels

# %%
Other_clean=clean_up_text(Other)
Other_label = classify_other_tweets(Other_clean,cl)

# %%
print Train_Label.shape
print CrossVal_Label.shape
print Test_Label.shape
print Other_label.shape
Total_label = np.append(Train_Label,CrossVal_Label,axis=0)
Total_label = np.append(Total_label,Test_Label, axis = 0)
Total_label = np.append(Total_label,Other_label, axis=0)
# Out:
# (200, 1)
# (60, 1)
# (40, 1)
# (3078, 1)

# %%
print Total_label.shape
# Out:
# (3378, 1)

# %%
np.save('Full_Tweet_Labels.npy',Total_label)

# %%
SBdf['label']=Total_label

# %%
SBdf
# Out:
#      followers_count                             location      screen_name  \
# 0               2989                    San Francisco, CA      beyondchron
# 1               2356                 Salt Lake City, Utah          MRC_SLC
# 2               1197                    San Francisco, CA    marcus_ismael
# 3                510                      Los Angeles, CA          Asmarcd
# 4                661                      California, USA   HousingHumanRt
# 5                797                        San Diego, CA      msmayarosas
# 6               1201        South LA, Boyle Hts, & beyond    sahrasulaiman
# 7               3797                        San Francisco         sutrofog
# 8               1677                     sutherland Shire  donaldh66287394
# 9                911                       Washington, DC   vanessabcalder
# 10             11869                       Sacramento, CA       dillonliam
# 11              4709                         Berkeley, CA         mateosfo
# 12               110                            BUF ➡️ LA   darryl_granger
# 13               494                          Oakland, CA     KyleAPennell
# 14               538                        San Francisco           torque
# 15              3287                 The Space Force Core    nyc_data_geek
# 16              2480           from Cleveland, in Oakland       dsmpowered
# 17               322                              Atlanta        TroyWhyte
# 18               695                           LA LA Land      melyssablue
# 19               425                              Vilnius          mgedmin
# 20              1629                  Bandis.Stockholm.se           GuSv01
# 21              4405            ÜT: 34.041042,-118.191894      kmontenegro
# 22               150                                              kdhively
# 23             33090                        San Francisco  SFBusinessTimes
# 24              3785                         Brooklyn, NY             mtsw
# 25                82                                              jcubsden
# 26              5486            L.A.via WashHts/HarlemNYC       tanlogadas
# 27             46886            San Francisco, California     Scott_Wiener
# 28               449                      Los Angeles, CA       cshepherds
# 29               483                        Mile High, CO     namhenderson
# ...              ...                                  ...              ...
# 3348              62                                       freddynietzschy
# 3349           27076  https://youtube.com/invisiblepeople     hardlynormal
# 3350              18                      Forest Hill Hex    ForestHillExt
# 3351              24                                       constituents381
# 3352             277                Van Nuys, Los Angeles     VoteForRoger
# 3353             153                         Berkeley, CA       mrlewis125
# 3354             365                          Los Angeles       jacobwooch
# 3355              12                             USA, USA   EpiphyteCities
# 3356              58                      Los Angeles, CA    DaShoeMonstar
# 3357            1370                   San Francisco, CA      marymcnamara
# 3358             431                    San Francisco, CA       irishbryan
# 3359            5238                        San Diego, CA  LisaHalverstadt
# 3360            7928                           Sacramento  MelodyGutierrez
# 3361             981                                          TaupeAvenger
# 3362              33                                          CAACentralCA
# 3363            1007                          Los Angeles       DuboffJess
# 3364            2936                    San Francisco, CA            SFHAC
# 3365             521                                            aceckhouse
# 3366            2168                          Oakland, CA   CitizenCassidy
# 3367             342                      Los Angeles, CA      nbousfield_
# 3368            1370                   San Francisco, CA      marymcnamara
# 3369            4739                       Sacramento, CA         Calefati
# 3370             227                    San Francisco, ca           donjay
# 3371            1597                      Los Angeles, CA       CleftClips
# 3372            1757                                          Saferhermosa
# 3373            2936                    San Francisco, CA            SFHAC
# 3374              11                                            JamesAria1
# 3375             340                        San Francisco        gillibits
# 3376            1195                     Toronto, Ontario  VoteTimGrantGPO
# 3377             243        Portland, OR Metopolitan Area         BranBrez
#
#                                                    text  \
# 0     Absolutely. And for all the fighting in SF, th...
# 1     RT @Tracktwentynine: Is it sad that the most t...
# 2     RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 a...
# 3     #Cities, if you were really upset about what #...
# 4     Housing Is A Human Right &amp; many other hous...
# 5     RT @cayimby: Profound thanks to Sen. @Scott_Wi...
# 6     RT @dillonliam: It’s officially dead #SB827. F...
# 7     RT @mikevladimer: @MarkLeno @AaronPeskin I gre...
# 8     RT @AlexSteffen: The single most powerful solu...
# 9     "The larger issue is that too many Democrats h...
# 10    One Senator speaking, one Senator opposed. Dem...
# 11    RT @michaeldlane: Boom!💥 Real progressives wo...
# 12    RT @cayimby: Your urgent advocacy for #SB827 m...
# 13                                #SB827 is dead. Dang.
# 14    RT @Scott_Wiener: 3/4 Angela Alioto is a good ...
# 15    RT @AlexSteffen: The early defeat of #SB827, C...
# 16    RT @damienISgoodmon: If a Senator w/a history ...
# 17    RT @byJoshuaDavis: Some white politicians are ...
# 18    RT @cayimby: “Legislator after legislator talk...
# 19    RT @uhshanti: I'm just hashtagging #SB827 so p...
# 20    RT @schmangee: I wonder if the Federal Transit...
# 21    RT @TenantsTogether: Anya at @Western_Center: ...
# 22    RT @theoverheadwire: This is the building that...
# 23    .@Scott_Wiener's housing-transit measure #SB82...
# 24    RT @SFyimby: Legislators seem to be letting th...
# 25    RT @justupthepike: #SB827 is already changing ...
# 26    RT @turbolars: to anyone in the #SanFrancisco ...
# 27    The @latimes opposed #SB827 because it actuall...
# 28    RT @EthanElkind: When #SB827 came out, I was a...
# 29    RT @ariellesallai: Thank fuck #SB827 is dead a...
# ...                                                 ...
# 3348  But then our body, as a saint in the backgroun...
# 3349  RT @rbramson: I feel like with the recent demi...
# 3350  RT @Scott_Wiener: Today #SB827 did not advance...
# 3351  @kimmaicutler CA needs to stop giving into the...
# 3352  RT @HousingHumanRt: And it's dead! Scott Wiene...
# 3353  RT @HousingHumanRt: And finally @BenAllenCA gi...
# 3354  RT @damienISgoodmon: The only votes sponsors @...
# 3355  RT @graue: If you support housing and transit ...
# 3356  RT @cayimby: Legislator after legislator talke...
# 3357  RT @jillstewart: Scott Wiener just praised his...
# 3358  RT @Scott_Wiener: 1/4 Leadership starts with b...
# 3359  RT @dillonliam: My first take on the demise of...
# 3360  .@Scott_Wiener now here and is about to take u...
# 3361  RT @aceckhouse: This bill is controversial bec...
# 3362  @Scott_Wiener @NeverSassyLaura. @yimbyaction\n...
# 3363  Reference to Rubio #CEQA bill by @TedGaines .....
# 3364  RT @HousingTrustSV: https://t.co/bZKLOrXai4 Th...
# 3365  lol Senator Beall is not pleased about Vice-Ma...
# 3366  RT @JerryJonesICLC: California's #SB827 is dea...
# 3367  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3368  RT @dillonliam: You may have heard that the co...
# 3369  Just walked into the @CALmatters office at 8:2...
# 3370  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3371  RT @ramez: I 100% agree with Alex. #SB827 was ...
# 3372  RT @Scott_Wiener: “We can have all the electri...
# 3373  RT @dillonliam: 🎉It’s #SB827 day🎉 A thread t...
# 3374  RT @jillstewart: Scott Wiener bill #SB827 defe...
# 3375  RT @IanCarlton: CA's #SB827 could have increas...
# 3376  RT @salimfurth: .@mattyglesias, @ebwhamilton a...
# 3377  RT @Scott_Wiener: Today #SB827 did not advance...
#
#                         time_zone  label
# 0      Pacific Time (US & Canada)    0.0
# 1     Mountain Time (US & Canada)    1.0
# 2      Pacific Time (US & Canada)    1.0
# 3      Pacific Time (US & Canada)    1.0
# 4                            None    0.0
# 5                            None    1.0
# 6                         Arizona    2.0
# 7      Pacific Time (US & Canada)    1.0
# 8                            None    1.0
# 9                            None    1.0
# 10     Pacific Time (US & Canada)    2.0
# 11     Pacific Time (US & Canada)    1.0
# 12     Pacific Time (US & Canada)    1.0
# 13                        Arizona    1.0
# 14     Pacific Time (US & Canada)    1.0
# 15                           None    1.0
# 16     Eastern Time (US & Canada)    0.0
# 17                     Georgetown    0.0
# 18     Pacific Time (US & Canada)    1.0
# 19                        Vilnius    2.0
# 20                      Stockholm    1.0
# 21     Pacific Time (US & Canada)    0.0
# 22                           None    1.0
# 23     Pacific Time (US & Canada)    1.0
# 24     Eastern Time (US & Canada)    1.0
# 25                           None    1.0
# 26                           None    1.0
# 27     Pacific Time (US & Canada)    1.0
# 28                         Alaska    1.0
# 29    Mountain Time (US & Canada)    0.0
# ...                           ...    ...
# 3348                         None    1.0
# 3349                Europe/London    1.0
# 3350                         None    1.0
# 3351                         None    0.0
# 3352                         None    0.0
# 3353                         None    0.0
# 3354                         None    0.0
# 3355                         None    1.0
# 3356                         None    1.0
# 3357   Pacific Time (US & Canada)    0.0
# 3358   Eastern Time (US & Canada)    1.0
# 3359   Pacific Time (US & Canada)    1.0
# 3360                       Alaska    1.0
# 3361   Pacific Time (US & Canada)    1.0
# 3362                         None    1.0
# 3363   Pacific Time (US & Canada)    1.0
# 3364   Pacific Time (US & Canada)    1.0
# 3365                         None    1.0
# 3366   Pacific Time (US & Canada)    1.0
# 3367   Pacific Time (US & Canada)    1.0
# 3368   Pacific Time (US & Canada)    1.0
# 3369   Pacific Time (US & Canada)    1.0
# 3370   Pacific Time (US & Canada)    1.0
# 3371          America/Los_Angeles    0.0
# 3372          America/Los_Angeles    1.0
# 3373   Pacific Time (US & Canada)    1.0
# 3374                         None    0.0
# 3375   Pacific Time (US & Canada)    0.0
# 3376   Eastern Time (US & Canada)    1.0
# 3377   Pacific Time (US & Canada)    1.0
#
# [3378 rows x 6 columns]

# %%
dffile = 'SB827df_with_labels.pkl'
SBdf.to_pickle(dffile)

# %%
dffile = 'SB827df_with_labels.pkl'
SBdf = pd.read_pickle(dffile)

# %%
SBdf.location.unique()
# Out:
# array([u'San Francisco, CA', u'Salt Lake City, Utah', u'Los Angeles, CA',
#        u'California, USA', u'San Diego, CA',
#        u'South LA, Boyle Hts, & beyond', u'San Francisco',
#        u'sutherland Shire', u'Washington, DC', u'Sacramento, CA',
#        u'Berkeley, CA', u'BUF \u27a1\ufe0f LA', u'Oakland, CA',
#        u'The Space Force Core', u'from Cleveland, in Oakland', u'Atlanta',
#        u'LA LA Land', u'Vilnius', u'Bandis.Stockholm.se',
#        u'\xdcT: 34.041042,-118.191894', u'', u'Brooklyn, NY',
#        u'L.A.via WashHts/HarlemNYC', u'San Francisco, California',
#        u'Mile High, CO', u'Silicon Valley | SF | 39.5K Ft',
#        u'Oakland, Calif.', u'upstate New York', u'NW LDN',
#        u'Los Angeles- Boston ', u'Minnesota, USA', u'Santa Monica, CA',
#        u'California', u'Seattle, WA', u'Phoenix, AZ', u'New Brunswick, NJ',
#        u'Olathe, KS', u'Southeast U.S.', u'Austin, TX', u'mourning',
#        u'DC by way of Upstate NY', u'Leimert Park, Los Angeles, CA',
#        u'Chicago, IL', u'Calgary', u'wandering the 3rd dimension',
#        u'Richmond, VA', u'Ohlone Land', u'USA, USA', u'Long Beach, CA',
#        u'Portland, OR', u'depends on momentum', u'Sacramento',
#        u'West Hartford, CT', u'Los Angeles', u'Brooklyn', u'DC USA',
#        u'Berkeley.', u'Between the bid and the ask', u'Philadelphia, PA',
#        u'United States', u'Arlington, VA', u'Silicon Valley',
#        u'Skagit, Washington State, USA', u'Sh\xef\u03c4cr\xe4terstania',
#        u'SF', u'Philly - San Francisco, CA', u'New Haven, CT',
#        u'San Francisco via ATL and NC', u'Toronto',
#        u'Somerville/S\xe3o Paulo/Joburg', u'East Bay',
#        u'San Francisco, CA (Occupied Ohlone Land)', u'South London',
#        u'los angeles ca', u'Wakanda by way of  Belize ', u'LA, CA',
#        u'Somerville, MA', u'Easy to find, hard to predict.',
#        u'Cole Valley, San Francisco', u'san diego, ca',
#        u'San Francisco - Bay Area', u'san diego ', u'New York',
#        u'Boston, MA', u'San Francisco, CA ', u'Rhode Island, USA',
#        u'Washington, D.C.', u'Los Angeles, CA 91601', u'Moon',
#        u'Oakland, CA and Portland, OR', u'SF Bay Area',
#        u'Pomona, California', u'NYC', u'occupied Ohlone land',
#        u'San Leandro, CA', u'San Diego, CA \u2022 he/him/his',
#        u'On the beach playing volleyball', u'San Francisco Ca',
#        u'Northridge, California', u'Oakland, California', u'Ventura, CA',
#        u'SoCal', u'Rockbridge Baths, VA',
#        u'West Valley, Silicon Valley CA', u'Olympic Tower', u'Vancouver',
#        u'Chicago/LaGrange/Itasca, IL', u'Santa Cruz County CA',
#        u'Burbank, CA', u'Boulder, Colorado, USA', u'Trump Train Station',
#        u'San Francisco, CA, USA', u'Boston', u'Oakland', u'Bay Area, CA',
#        u'San Francisco Bay Area', u'Sunnyvale, CA', u'fremont, seattle',
#        u'Los Altos, CA', u'New York, NY', u'Charlotte', u'Berkeley CA',
#        u'Oakton, Virginia', u'Join the movement!', u'Texas',
#        u'Vancouver - LA', u'La Lengua, SF', u'northern CA',
#        u'Bangalore, India', u'Pasadena, CA', u'Los Angeles Metro Area',
#        u'Dorchester, MA', u'Durham, NC', u'Bay Area', u'he/him',
#        u'Santa Clara County, CA', u'Incomplete Streets, CA', u'Various',
#        u'Helsinki, Suomi', u'Miami, SF & Global',
#        u'john.myers@latimes.com', u'Melbourne, VIC, Australia',
#        u'San Rafael', u'DC via Lancaster, PA', u'Montague, Massachusetts',
#        u'Palo Alto, CA', u'Twin Cities, Minnesota', u'chicago', u'Norwich',
#        u'Pendleton, OR', u'LA, Gual\xe1n, Hamburg', u'Detroit suburbs',
#        u'Cambridge, England', u'San Mateo County, Calif.',
#        u'Azusa Tar Pits', u'SF Bay Area, CA', u'Rhode Island',
#        u'Frankfurt, Germany', u'State College, PA', u'Glendale',
#        u'Canada, India, USA', u'Texas, USA', u'Earth', u'cyberspace',
#        u'San Jose, CA', u'.', u'Marinwood, CA',
#        u'Gluten\u2019s Heart of Darkness', u'Northern California',
#        u'Rosemead, CA', u'union. somerville. ma. usa.',
#        u'New York City & Southeastern CT', u'Honolulu/No. Cal.',
#        u'Berkeley, California', u'WA', u'Nowhere, especially not LA',
#        u'Vancouver,B.C.', u'Arlington, MA', u'Somewhere',
#        u'Mid-City West, Los Angeles', u'Bethlehem, Pennsylvania',
#        u'CALIFORNIA ~ South & North  ', u'Memphis, TN',
#        u'Dublin City, Ireland', u'Chico, CA', u'Walnut Creek, CA',
#        u'Oakland, California; Toronto; Portland; global', u'Guinea Bissau',
#        u'Muncie, IN', u'Fremont, CA', u'my old oakland home',
#        u'Los Angeles, CA, USA', u'Occupied Ohlone territory', u'Manhattan',
#        u'Charlottesville, VA, USA', u'Denver, CO',
#        u'Free Imperial City of San Francisco', u'Seaside, California, USA',
#        u'District of Columbia, USA', u'Outer Sunset, San Francisco',
#        u'Sodom-on-the-Bay, California', u'90065', u'Boulder, CO',
#        u'Redondo Beach', u'Omaha, NE', u'New York City', u'San Ramon, CA',
#        u' USA', u'Portland, Oregon', u'Newark, NJ', u'pond',
#        u'The Based North', u'Beverly Hills, Stockholm', u'Fresno',
#        u'Belmont Shore (Long Beach) CA', u'Out of this world\xbbSFC  ',
#        u'\u2514A', u'34.020623,-118.289693', u'central Florida',
#        u'National City, CA', u'South Los Angeles', u'Stanford, CA',
#        u'santa cruz, ca', u'USA', u'Cambridge, MA',
#        u'\xdcT: 41.991823,-70.716601', u'Rialto, CA',
#        u'Rose Hill, New York, NY', u'America',
#        u'Prob somewhere watching Logan', u'Oxnard CA ', u'Atlanta, GA',
#        u'Providence, RI', u'berkeley, ca', u'My company is @CreativeSage',
#        u'Tampa, FL', u'Excelsior, San Francisco ', u'Muwekma Ohlone Land',
#        u'Fullerton, CA', u'Khar, Bajaur Agency', u'West of Oz',
#        u'Olympia, WA', u'El Portal', u'Beverly Hills, CA',
#        u'SoCal/St. Louis', u'Canada', u'fishin 4 good perch',
#        u'Roxbury, Boston', u'510', u'Columbus, OH', u'Emeryville, CA',
#        u'West Coast', u'Englewood, CO', u'North Carolina, USA',
#        u'Tenderloin, San Francisco', u'New York, USA', u'Toronto, Canada',
#        u'SF | LA | NY | CHI | Paris', u'san francisco',
#        u'Orange County, CA', u'Oakland, Calif',
#        u'Usually Malaysia or the US', u'Harvard University',
#        u'San Carlos, CA', u'Larkspur, CA, USA', u'west phila best phila',
#        u'SF Bay Area Peninsula', u'Redwood City, CA',
#        u'Wherever permits can be pulled', u'Minneapolis, MN',
#        u'Denton, TX', u'Sucka Free City', u'Southern California',
#        u'Rocklin, CA', u'near the shellmound',
#        u'San Francisco & Davis, CA', u'Modesto, CA', u'Venice, CA',
#        u'Lafayette, CA', u'Menlo Park, CA', u'Healdsburg, CA',
#        u'Vancouver, British Columbia', u'Minneapolis',
#        u'Los Angeles, California', u'Berkeley, California, USA',
#        u'washington dc', u'Diamond Heights, San Francisco',
#        u'Newport Beach, CA', u'Bedford Hills, NY',
#        u'iPhone: 39.905247,-86.219940', u"St. John's, Canada",
#        u'Daly City, CA', u'La Mesa, CA', u'New York, New York',
#        u'iPhone: 35.912838,-79.048080', u'Chicago / NYC / High Point',
#        u'Davos, Switzerland', u'San Francisco, CA USA',
#        u'Toronto, Ontario', u'San Diego, California', u'West Coast USA',
#        u'Minneapolis, colonized Dakota land',
#        u'San Francisco Teocuitlatepec, CA', u'Montclair, NJ',
#        u'Seattle, Washington, USA', u'Chicago', u'San Diego', u'DC & CA',
#        u'Sac-Toe CA', u'Stolen Tongva Land', u'Raleigh, NC',
#        u'Agoura Hills, CA', u'North America', u'SF, CA', u'UC Berkeley',
#        u'boston ish', u'Brea, CA', u'Buenos Aires, Argentina',
#        u'Monterey County', u'San Francisco, Caliornia USA',
#        u'Grant Road Sylvan Park Area, Mountain View', u'Cascadia',
#        u'The Numbers, Portland, OR', u'Dallas, TX',
#        u'Lower Haight, San Francisco', u'Union City, CA',
#        u'Kawasaki-shi Miyamae, Kanagawa', u'pacific rim', u'SF, ATX, SATX',
#        u'Maplewood, NJ', u'Alameda, CA and Sonora, CA', u'Manhattan/NYC',
#        u'Alameda, CA', u'Oakland, Ca', u'Wakefield, MA',
#        u'chicago \U0001f315 palo alto', u'Brooklyn, NY//Oakland, CA',
#        u'Van Nuys, Los Angeles', u'Northern California ',
#        u'Rohnert Park, CA', u'Sacramento, Reno & Tahoe',
#        u'SF Bay Peninsula', u'Seattle', u'Bakersfield, California',
#        u'ABQ NM', u'St Petersburg, FL', u'Oaklandish', u'Pleasanton, CA',
#        u'berlin | the future', u'Glendale, California', u'Italy',
#        u'Portland, OR Metopolitan Area', u'\xdcT: 37.770364,-122.410351',
#        u'DC', u'North Carolina', u'San Francisco, California, USA',
#        u'Washington DC', u'San Francisco & Global',
#        u'Inner Sunset, San Francisco', u'Wall Street', u'Houston',
#        u'Contra Costa County, CA', u'Manassas, VA', u'Empire State',
#        u'\u2665 \u262f \u2665', u'Cambridge, Mass.', u'China',
#        u'Buenos Aires', u'Washington D.C.', u'Lafayette, IN',
#        u'Puget Sound, WA', u'Oakland CA', u'Redmond, WA',
#        u'Vancouver, BC, Canada', u'Bernal Heights',
#        u'Toronto, Ontario, Canada', u'San Francisco CA & Naoned BZH',
#        u'Fairfield, CA', u'New York,New York', u'Charlotte, NC', u'Dorset',
#        u'Knoxville Tennessee', u'Los Angeles, California, USA',
#        u'minneapolis, mn', u'Indianapolis', u'Global',
#        u'Silicon Valley, CA', u'Mountain View, CA', u'Bronx, NY',
#        u'Wisconsin, USA', u'DC via Appalachia', u'Ca, Co, NY, Fl, Ak, USA',
#        u'Elysian Valley, Los Angeles', u'Manhattan, NYC',
#        u'Port Harcourt, Nigeria', u'South Bay. SF.', u'DC Suburbs',
#        u'California Republic', u'San Jose, Calif. USA', u'Longview, TX',
#        u'CA', u'Oaktown by the Lake', u'United States of America',
#        u'Rockville, MD', u'Barrio Echo Parque, Alta Calif',
#        u'Mill Valley, CA', u'The HIVEMIND, RNC HQ',
#        u'37.472088,-122.221390', u'\u2708\ufe0f',
#        u'South Central Los Angeles', u'Cambridge MA', u'Silver Spring, MD',
#        u'Anaheim, CA', u'Dathomir', u'Redondo Beach, CA',
#        u'SoMa, San Francisco', u'Davis, CA', u'Lancaster, PA',
#        u'DC, Chicago, SF, NYC', u'Santa Barbara',
#        u'Redwood City, CA | Los Angeles', u'\xdcT: 37.603539,-122.385962',
#        u'SF, CA 94116', u"Bay Area's Black Wall Street",
#        u'San Francisco, CA \U0001f1fa\U0001f1f8', u'Berkeley, CA, 1970',
#        u'Boyle Heights, California', u'Santa Clara, CA', u'World Citizen',
#        u"Banker's Hill, San Diego", u'downtown San Jose, CA',
#        u'\u2736\u2736\u2736\u2736, il', u'Oakland & California',
#        u'San Francisco CA', u'Mississippi, USA', u'los angeles',
#        u'Based in Los Angeles', u'West Hollywood, CA', u'Sausalito, CA',
#        u'So Cal', u'Westwood Park, San Francisco',
#        u'm@mschade.me \xb7 San Francisco', u'Ireland, Lebanon, Palestine',
#        u'College Park, MD',
#        u'Brooklyn West. Less public transit, but better tacos.',
#        u'Oregon, USA', u'Boshwash Megalolpolis',
#        u'San Francisco and Oakland, CA', u'Dogpatch, San Francisco',
#        u'#thistown', u'Fern Street, San Francisco', u'SFO',
#        u'los angeles, ca', u'San Francisco Bay Area, CA',
#        u'Bay Area, California', u'Union, NJ', u'El Cerrito, CA', u'NORCAL',
#        u'Oakland, CA and beyond', u'NC \u27a1\ufe0f CA',
#        u'London, England', u'san francisco, ca', u'Alexandria, VA',
#        u'republic of the spirit', u'San Leandro and Oakland, CA',
#        u'El Cerrito, California', u'Orange County, California',
#        u'Greater Vancouver', u'Mountain View, CA, US', u'San Jose',
#        u'France', u'Flagstaff, AZ', u'Belmont, CA',
#        u'3rd planet in minor solar sys', u'Indianapolis, IN',
#        u'Santa Cruz, CA', u'Eugene, OR', u'901 Monroe Adjacent',
#        u'Pacifica, CA', u'SF, Silicon Valley and beyond',
#        u'Porto Alegre, Brazil', u'San Jose, California',
#        u'Fairfax County, VA', u'Auburn, AL', u'Irvine, CA',
#        u'Guadalajara, Jalisco', u'Iowa City, Iowa', u'Orlando, FL',
#        u'At sea on the Hansa Freyburg',
#        u'LA \u2708\ufe0f NYC \u2708\ufe0f SF', u'Irvine', u'Richmond, CA',
#        u'Pittsburgh, PA', u'Summerside, PE, Canada', u'Bump City, CA',
#        u'SF, CA via South Dakota', u'Bremerton WA', u'Australia',
#        u' Los Angeles ', u'San Francisco, North America',
#        u'Ottawa, Canada', u'SF Bay Area, USA', u'Salinas, CA',
#        u'Kansas, USA', u'Bloom 4 Assembly FPPC#1392468', u'In the desert.',
#        u'Lincoln Heights, CA', u'Marin County, California',
#        u'Planet Earth', u'Gay space communist colony',
#        u'Body: SF, Spirit Animal: CO', u'Los Osos, CA',
#        u'New York | Boston', u'Born to Lose, Live to Win', u'earth',
#        u'Woodley Park, DC', u'Sierras & Half Moon Bay CA',
#        u'San Francisco Chronicle', u'Oakland, CA, USA ',
#        u'Charlottesville, VA', u'London | Birmingham', u'Woodside, CA',
#        u'Washington DC, United States', u'Manhattan, NY',
#        u'Socialist hellscape', u'PDX, DC, NC',
#        u'The Ancient Shore of Laurentia', u'Westwood, Los Angeles',
#        u'where the Tweets flow', u'Somewhere in hell. ', u'DTLA',
#        u'Dublin, Ireland and California', u'Body: DC. Soul: Boston.',
#        u'La Misi\xf3n, San Francisco', u'Glendale, CA', u'Mostly Berlin',
#        u'Fresno, CA', u'Napa, CA', u'Tokyo',
#        u'Chicago ex-pat in Los Angeles', u'The Dance Archipelago',
#        u'Vancouver, BC', u'Houston, Texas', u'Front Range, CO',
#        u'Huntington Beach, CA', u'OR/CA/DC/NY', u'Washington, DC, USA',
#        u'South San Francisco, CA', u'Savannah, GA', u'Cleveland',
#        u'Durham, NC, USA', u'Placerville, CA', u'Parts unknown',
#        u'Everywhere', u'Idaho, USA', u'Bradenton, FL',
#        u'East Coast! Fuck You!', u'Berkeley', u'Utah',
#        u'Ohlone land (University Ave)', u'San Francisco, ca',
#        u'The Haight, San Francisco', u'Vancouver, Canada',
#        u'San Francisco via Adelaide', u'PGP: http://bit.ly/1Nja4jP',
#        u'Greenwich, UK', u'Fake, non rural America. City of Roses, OR.',
#        u'Buffalo, NY', u'Riyadh', u'Houston, TX', u'Ambivalent Angelenx',
#        u'Studio City, CA', u'Brooklyn and Queens',
#        u'LA via NY via SP via SF', u'San Francisco, CA, US', u'Newton, MA',
#        u'san francisco | sacramento', u'Greater Midwest',
#        u'Redding, Calif.', u'Sacramento, CA ', u'Purgatory',
#        u'Seattle, WA, USA', u'San Francisco, Silicon Valley',
#        u'South San Francisco, CA, USA', u'Portland, OR USA',
#        u'Bay area, CA', u'Irving, Texas', u'Costa Mesa, CA',
#        u'South Carolina, USA', u'NYC, RDU, AXA, ANU', u'Providence',
#        u'San Francisco, The Internet', u'Ray Romano, Ray Romano', u'CA 49',
#        u'SF,CA + PDX,Cascadia', u'SF Bay Area, California', u'Brooklyn NY',
#        u'Albuquerque, NM', u'EARTH ', u'Kirkland WA', u'New World Order',
#        u'St. Petersburg, FL', u'Sydney, Australia', u'Normal, IL',
#        u'Newark/NOLA', u'Adult Neurology',
#        u'Sacramento,CA (City of Dreams)', u'SFO (via EWR - BIO - DCA)',
#        u'Livermore, CA', u'Colombia', u'The Excelsior', u'Decatur, GA',
#        u'Homey Nation of KSPB', u'Holyoke, MA',
#        u'Austin, TX via Nawf Dallas, TX', u'St. Louis, MO- south city',
#        u'Athens, Georgia', u'Minnesota | Austin, Texas', u'new york',
#        u'Greater Seattle area', u'iPhone: 49.284729,-123.109573',
#        u'Innisfil , ON', u'100% DEATH TAX', u'Barstow, CA',
#        u'Metairie, LA', u'Van Nuys, CA', u'Ajax. Ontario Canada',
#        u' Toronto and Vancouver', u'Multnomah land ', u'Springfield, MA',
#        u'Deep State, NJ ', u'Cupertino, California', u'Paris, France',
#        u'Nomidlats', u'Monterrey, Nuevo Le\xf3n', u'Seattle\n', u'London',
#        u'San Francisco Mission District', u'Spuyten Duyvil, Bronx',
#        u'NY/NJ', u'Iowa City, IA',
#        u'San Francisco\u2022Oakland\u2022San Jose',
#        u'Chicago Botanic Garden', u'South Florida, U.S.A.',
#        u'South Pasadena, CA', u'CaliforNoThankYou\u270b\U0001f3fd',
#        u'https://youtube.com/invisiblepeople', u'Forest Hill Hex'], dtype=object)

# %% [markdown]
# There's a mixture of Californian locals and people from far-flung regions of the globe in this dataframe. My suspicion would be that the non-locals are overwhelming in support of this measure (otherwise why would they bother tracking it) whereas the Californians may be more divided. So I'm going to try to sort this out.

# %%
def west_coast_california(df): #pretends being on the west coast is equivalent to being Californian
    Time_Zones = df.time_zone
    People = df.shape[0]
    Californian = np.zeros([People,1])
    for i in range(People):
        if Time_Zones.loc[i]=="Pacific Time (US & Canada)":
            Californian[i]=1
        else:
            Californian[i]=0
    return Californian

# %% [markdown]
# The West Coast Californian function is pretty rudamentary. This could be improved by first trying to classify the location as containing words that indicate a location in California and then defaulting to using the time zone if no location is provided.

# %%
californian_array = west_coast_california(SBdf)

# %%
SBdf['californian']=californian_array

# %%
SBdf
# Out:
#      followers_count                             location      screen_name  \
# 0               2989                    San Francisco, CA      beyondchron
# 1               2356                 Salt Lake City, Utah          MRC_SLC
# 2               1197                    San Francisco, CA    marcus_ismael
# 3                510                      Los Angeles, CA          Asmarcd
# 4                661                      California, USA   HousingHumanRt
# 5                797                        San Diego, CA      msmayarosas
# 6               1201        South LA, Boyle Hts, & beyond    sahrasulaiman
# 7               3797                        San Francisco         sutrofog
# 8               1677                     sutherland Shire  donaldh66287394
# 9                911                       Washington, DC   vanessabcalder
# 10             11869                       Sacramento, CA       dillonliam
# 11              4709                         Berkeley, CA         mateosfo
# 12               110                            BUF ➡️ LA   darryl_granger
# 13               494                          Oakland, CA     KyleAPennell
# 14               538                        San Francisco           torque
# 15              3287                 The Space Force Core    nyc_data_geek
# 16              2480           from Cleveland, in Oakland       dsmpowered
# 17               322                              Atlanta        TroyWhyte
# 18               695                           LA LA Land      melyssablue
# 19               425                              Vilnius          mgedmin
# 20              1629                  Bandis.Stockholm.se           GuSv01
# 21              4405            ÜT: 34.041042,-118.191894      kmontenegro
# 22               150                                              kdhively
# 23             33090                        San Francisco  SFBusinessTimes
# 24              3785                         Brooklyn, NY             mtsw
# 25                82                                              jcubsden
# 26              5486            L.A.via WashHts/HarlemNYC       tanlogadas
# 27             46886            San Francisco, California     Scott_Wiener
# 28               449                      Los Angeles, CA       cshepherds
# 29               483                        Mile High, CO     namhenderson
# ...              ...                                  ...              ...
# 3348              62                                       freddynietzschy
# 3349           27076  https://youtube.com/invisiblepeople     hardlynormal
# 3350              18                      Forest Hill Hex    ForestHillExt
# 3351              24                                       constituents381
# 3352             277                Van Nuys, Los Angeles     VoteForRoger
# 3353             153                         Berkeley, CA       mrlewis125
# 3354             365                          Los Angeles       jacobwooch
# 3355              12                             USA, USA   EpiphyteCities
# 3356              58                      Los Angeles, CA    DaShoeMonstar
# 3357            1370                   San Francisco, CA      marymcnamara
# 3358             431                    San Francisco, CA       irishbryan
# 3359            5238                        San Diego, CA  LisaHalverstadt
# 3360            7928                           Sacramento  MelodyGutierrez
# 3361             981                                          TaupeAvenger
# 3362              33                                          CAACentralCA
# 3363            1007                          Los Angeles       DuboffJess
# 3364            2936                    San Francisco, CA            SFHAC
# 3365             521                                            aceckhouse
# 3366            2168                          Oakland, CA   CitizenCassidy
# 3367             342                      Los Angeles, CA      nbousfield_
# 3368            1370                   San Francisco, CA      marymcnamara
# 3369            4739                       Sacramento, CA         Calefati
# 3370             227                    San Francisco, ca           donjay
# 3371            1597                      Los Angeles, CA       CleftClips
# 3372            1757                                          Saferhermosa
# 3373            2936                    San Francisco, CA            SFHAC
# 3374              11                                            JamesAria1
# 3375             340                        San Francisco        gillibits
# 3376            1195                     Toronto, Ontario  VoteTimGrantGPO
# 3377             243        Portland, OR Metopolitan Area         BranBrez
#
#                                                    text  \
# 0     Absolutely. And for all the fighting in SF, th...
# 1     RT @Tracktwentynine: Is it sad that the most t...
# 2     RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 a...
# 3     #Cities, if you were really upset about what #...
# 4     Housing Is A Human Right &amp; many other hous...
# 5     RT @cayimby: Profound thanks to Sen. @Scott_Wi...
# 6     RT @dillonliam: It’s officially dead #SB827. F...
# 7     RT @mikevladimer: @MarkLeno @AaronPeskin I gre...
# 8     RT @AlexSteffen: The single most powerful solu...
# 9     "The larger issue is that too many Democrats h...
# 10    One Senator speaking, one Senator opposed. Dem...
# 11    RT @michaeldlane: Boom!💥 Real progressives wo...
# 12    RT @cayimby: Your urgent advocacy for #SB827 m...
# 13                                #SB827 is dead. Dang.
# 14    RT @Scott_Wiener: 3/4 Angela Alioto is a good ...
# 15    RT @AlexSteffen: The early defeat of #SB827, C...
# 16    RT @damienISgoodmon: If a Senator w/a history ...
# 17    RT @byJoshuaDavis: Some white politicians are ...
# 18    RT @cayimby: “Legislator after legislator talk...
# 19    RT @uhshanti: I'm just hashtagging #SB827 so p...
# 20    RT @schmangee: I wonder if the Federal Transit...
# 21    RT @TenantsTogether: Anya at @Western_Center: ...
# 22    RT @theoverheadwire: This is the building that...
# 23    .@Scott_Wiener's housing-transit measure #SB82...
# 24    RT @SFyimby: Legislators seem to be letting th...
# 25    RT @justupthepike: #SB827 is already changing ...
# 26    RT @turbolars: to anyone in the #SanFrancisco ...
# 27    The @latimes opposed #SB827 because it actuall...
# 28    RT @EthanElkind: When #SB827 came out, I was a...
# 29    RT @ariellesallai: Thank fuck #SB827 is dead a...
# ...                                                 ...
# 3348  But then our body, as a saint in the backgroun...
# 3349  RT @rbramson: I feel like with the recent demi...
# 3350  RT @Scott_Wiener: Today #SB827 did not advance...
# 3351  @kimmaicutler CA needs to stop giving into the...
# 3352  RT @HousingHumanRt: And it's dead! Scott Wiene...
# 3353  RT @HousingHumanRt: And finally @BenAllenCA gi...
# 3354  RT @damienISgoodmon: The only votes sponsors @...
# 3355  RT @graue: If you support housing and transit ...
# 3356  RT @cayimby: Legislator after legislator talke...
# 3357  RT @jillstewart: Scott Wiener just praised his...
# 3358  RT @Scott_Wiener: 1/4 Leadership starts with b...
# 3359  RT @dillonliam: My first take on the demise of...
# 3360  .@Scott_Wiener now here and is about to take u...
# 3361  RT @aceckhouse: This bill is controversial bec...
# 3362  @Scott_Wiener @NeverSassyLaura. @yimbyaction\n...
# 3363  Reference to Rubio #CEQA bill by @TedGaines .....
# 3364  RT @HousingTrustSV: https://t.co/bZKLOrXai4 Th...
# 3365  lol Senator Beall is not pleased about Vice-Ma...
# 3366  RT @JerryJonesICLC: California's #SB827 is dea...
# 3367  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3368  RT @dillonliam: You may have heard that the co...
# 3369  Just walked into the @CALmatters office at 8:2...
# 3370  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3371  RT @ramez: I 100% agree with Alex. #SB827 was ...
# 3372  RT @Scott_Wiener: “We can have all the electri...
# 3373  RT @dillonliam: 🎉It’s #SB827 day🎉 A thread t...
# 3374  RT @jillstewart: Scott Wiener bill #SB827 defe...
# 3375  RT @IanCarlton: CA's #SB827 could have increas...
# 3376  RT @salimfurth: .@mattyglesias, @ebwhamilton a...
# 3377  RT @Scott_Wiener: Today #SB827 did not advance...
#
#                         time_zone  label  californian
# 0      Pacific Time (US & Canada)    0.0          1.0
# 1     Mountain Time (US & Canada)    1.0          0.0
# 2      Pacific Time (US & Canada)    1.0          1.0
# 3      Pacific Time (US & Canada)    1.0          1.0
# 4                            None    0.0          0.0
# 5                            None    1.0          0.0
# 6                         Arizona    2.0          0.0
# 7      Pacific Time (US & Canada)    1.0          1.0
# 8                            None    1.0          0.0
# 9                            None    1.0          0.0
# 10     Pacific Time (US & Canada)    2.0          1.0
# 11     Pacific Time (US & Canada)    1.0          1.0
# 12     Pacific Time (US & Canada)    1.0          1.0
# 13                        Arizona    1.0          0.0
# 14     Pacific Time (US & Canada)    1.0          1.0
# 15                           None    1.0          0.0
# 16     Eastern Time (US & Canada)    0.0          0.0
# 17                     Georgetown    0.0          0.0
# 18     Pacific Time (US & Canada)    1.0          1.0
# 19                        Vilnius    2.0          0.0
# 20                      Stockholm    1.0          0.0
# 21     Pacific Time (US & Canada)    0.0          1.0
# 22                           None    1.0          0.0
# 23     Pacific Time (US & Canada)    1.0          1.0
# 24     Eastern Time (US & Canada)    1.0          0.0
# 25                           None    1.0          0.0
# 26                           None    1.0          0.0
# 27     Pacific Time (US & Canada)    1.0          1.0
# 28                         Alaska    1.0          0.0
# 29    Mountain Time (US & Canada)    0.0          0.0
# ...                           ...    ...          ...
# 3348                         None    1.0          0.0
# 3349                Europe/London    1.0          0.0
# 3350                         None    1.0          0.0
# 3351                         None    0.0          0.0
# 3352                         None    0.0          0.0
# 3353                         None    0.0          0.0
# 3354                         None    0.0          0.0
# 3355                         None    1.0          0.0
# 3356                         None    1.0          0.0
# 3357   Pacific Time (US & Canada)    0.0          1.0
# 3358   Eastern Time (US & Canada)    1.0          0.0
# 3359   Pacific Time (US & Canada)    1.0          1.0
# 3360                       Alaska    1.0          0.0
# 3361   Pacific Time (US & Canada)    1.0          1.0
# 3362                         None    1.0          0.0
# 3363   Pacific Time (US & Canada)    1.0          1.0
# 3364   Pacific Time (US & Canada)    1.0          1.0
# 3365                         None    1.0          0.0
# 3366   Pacific Time (US & Canada)    1.0          1.0
# 3367   Pacific Time (US & Canada)    1.0          1.0
# 3368   Pacific Time (US & Canada)    1.0          1.0
# 3369   Pacific Time (US & Canada)    1.0          1.0
# 3370   Pacific Time (US & Canada)    1.0          1.0
# 3371          America/Los_Angeles    0.0          0.0
# 3372          America/Los_Angeles    1.0          0.0
# 3373   Pacific Time (US & Canada)    1.0          1.0
# 3374                         None    0.0          0.0
# 3375   Pacific Time (US & Canada)    0.0          1.0
# 3376   Eastern Time (US & Canada)    1.0          0.0
# 3377   Pacific Time (US & Canada)    1.0          1.0
#
# [3378 rows x 7 columns]

# %%
sum(SBdf.californian)
# Out:
# 1750.0

# %%
sum(SBdf.label)
# Out:
# 2532.0

# %%
dffile = 'SB827df_with_californians.pkl'
SBdf.to_pickle(dffile)

# %%
dffile = 'SB827df_with_californians.pkl'
SBdf = pd.read_pickle(dffile)

# %%
SBdf
# Out:
#      followers_count                             location      screen_name  \
# 0               2989                    San Francisco, CA      beyondchron
# 1               2356                 Salt Lake City, Utah          MRC_SLC
# 2               1197                    San Francisco, CA    marcus_ismael
# 3                510                      Los Angeles, CA          Asmarcd
# 4                661                      California, USA   HousingHumanRt
# 5                797                        San Diego, CA      msmayarosas
# 6               1201        South LA, Boyle Hts, & beyond    sahrasulaiman
# 7               3797                        San Francisco         sutrofog
# 8               1677                     sutherland Shire  donaldh66287394
# 9                911                       Washington, DC   vanessabcalder
# 10             11869                       Sacramento, CA       dillonliam
# 11              4709                         Berkeley, CA         mateosfo
# 12               110                            BUF ➡️ LA   darryl_granger
# 13               494                          Oakland, CA     KyleAPennell
# 14               538                        San Francisco           torque
# 15              3287                 The Space Force Core    nyc_data_geek
# 16              2480           from Cleveland, in Oakland       dsmpowered
# 17               322                              Atlanta        TroyWhyte
# 18               695                           LA LA Land      melyssablue
# 19               425                              Vilnius          mgedmin
# 20              1629                  Bandis.Stockholm.se           GuSv01
# 21              4405            ÜT: 34.041042,-118.191894      kmontenegro
# 22               150                                              kdhively
# 23             33090                        San Francisco  SFBusinessTimes
# 24              3785                         Brooklyn, NY             mtsw
# 25                82                                              jcubsden
# 26              5486            L.A.via WashHts/HarlemNYC       tanlogadas
# 27             46886            San Francisco, California     Scott_Wiener
# 28               449                      Los Angeles, CA       cshepherds
# 29               483                        Mile High, CO     namhenderson
# ...              ...                                  ...              ...
# 3348              62                                       freddynietzschy
# 3349           27076  https://youtube.com/invisiblepeople     hardlynormal
# 3350              18                      Forest Hill Hex    ForestHillExt
# 3351              24                                       constituents381
# 3352             277                Van Nuys, Los Angeles     VoteForRoger
# 3353             153                         Berkeley, CA       mrlewis125
# 3354             365                          Los Angeles       jacobwooch
# 3355              12                             USA, USA   EpiphyteCities
# 3356              58                      Los Angeles, CA    DaShoeMonstar
# 3357            1370                   San Francisco, CA      marymcnamara
# 3358             431                    San Francisco, CA       irishbryan
# 3359            5238                        San Diego, CA  LisaHalverstadt
# 3360            7928                           Sacramento  MelodyGutierrez
# 3361             981                                          TaupeAvenger
# 3362              33                                          CAACentralCA
# 3363            1007                          Los Angeles       DuboffJess
# 3364            2936                    San Francisco, CA            SFHAC
# 3365             521                                            aceckhouse
# 3366            2168                          Oakland, CA   CitizenCassidy
# 3367             342                      Los Angeles, CA      nbousfield_
# 3368            1370                   San Francisco, CA      marymcnamara
# 3369            4739                       Sacramento, CA         Calefati
# 3370             227                    San Francisco, ca           donjay
# 3371            1597                      Los Angeles, CA       CleftClips
# 3372            1757                                          Saferhermosa
# 3373            2936                    San Francisco, CA            SFHAC
# 3374              11                                            JamesAria1
# 3375             340                        San Francisco        gillibits
# 3376            1195                     Toronto, Ontario  VoteTimGrantGPO
# 3377             243        Portland, OR Metopolitan Area         BranBrez
#
#                                                    text  \
# 0     Absolutely. And for all the fighting in SF, th...
# 1     RT @Tracktwentynine: Is it sad that the most t...
# 2     RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 a...
# 3     #Cities, if you were really upset about what #...
# 4     Housing Is A Human Right &amp; many other hous...
# 5     RT @cayimby: Profound thanks to Sen. @Scott_Wi...
# 6     RT @dillonliam: It’s officially dead #SB827. F...
# 7     RT @mikevladimer: @MarkLeno @AaronPeskin I gre...
# 8     RT @AlexSteffen: The single most powerful solu...
# 9     "The larger issue is that too many Democrats h...
# 10    One Senator speaking, one Senator opposed. Dem...
# 11    RT @michaeldlane: Boom!💥 Real progressives wo...
# 12    RT @cayimby: Your urgent advocacy for #SB827 m...
# 13                                #SB827 is dead. Dang.
# 14    RT @Scott_Wiener: 3/4 Angela Alioto is a good ...
# 15    RT @AlexSteffen: The early defeat of #SB827, C...
# 16    RT @damienISgoodmon: If a Senator w/a history ...
# 17    RT @byJoshuaDavis: Some white politicians are ...
# 18    RT @cayimby: “Legislator after legislator talk...
# 19    RT @uhshanti: I'm just hashtagging #SB827 so p...
# 20    RT @schmangee: I wonder if the Federal Transit...
# 21    RT @TenantsTogether: Anya at @Western_Center: ...
# 22    RT @theoverheadwire: This is the building that...
# 23    .@Scott_Wiener's housing-transit measure #SB82...
# 24    RT @SFyimby: Legislators seem to be letting th...
# 25    RT @justupthepike: #SB827 is already changing ...
# 26    RT @turbolars: to anyone in the #SanFrancisco ...
# 27    The @latimes opposed #SB827 because it actuall...
# 28    RT @EthanElkind: When #SB827 came out, I was a...
# 29    RT @ariellesallai: Thank fuck #SB827 is dead a...
# ...                                                 ...
# 3348  But then our body, as a saint in the backgroun...
# 3349  RT @rbramson: I feel like with the recent demi...
# 3350  RT @Scott_Wiener: Today #SB827 did not advance...
# 3351  @kimmaicutler CA needs to stop giving into the...
# 3352  RT @HousingHumanRt: And it's dead! Scott Wiene...
# 3353  RT @HousingHumanRt: And finally @BenAllenCA gi...
# 3354  RT @damienISgoodmon: The only votes sponsors @...
# 3355  RT @graue: If you support housing and transit ...
# 3356  RT @cayimby: Legislator after legislator talke...
# 3357  RT @jillstewart: Scott Wiener just praised his...
# 3358  RT @Scott_Wiener: 1/4 Leadership starts with b...
# 3359  RT @dillonliam: My first take on the demise of...
# 3360  .@Scott_Wiener now here and is about to take u...
# 3361  RT @aceckhouse: This bill is controversial bec...
# 3362  @Scott_Wiener @NeverSassyLaura. @yimbyaction\n...
# 3363  Reference to Rubio #CEQA bill by @TedGaines .....
# 3364  RT @HousingTrustSV: https://t.co/bZKLOrXai4 Th...
# 3365  lol Senator Beall is not pleased about Vice-Ma...
# 3366  RT @JerryJonesICLC: California's #SB827 is dea...
# 3367  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3368  RT @dillonliam: You may have heard that the co...
# 3369  Just walked into the @CALmatters office at 8:2...
# 3370  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3371  RT @ramez: I 100% agree with Alex. #SB827 was ...
# 3372  RT @Scott_Wiener: “We can have all the electri...
# 3373  RT @dillonliam: 🎉It’s #SB827 day🎉 A thread t...
# 3374  RT @jillstewart: Scott Wiener bill #SB827 defe...
# 3375  RT @IanCarlton: CA's #SB827 could have increas...
# 3376  RT @salimfurth: .@mattyglesias, @ebwhamilton a...
# 3377  RT @Scott_Wiener: Today #SB827 did not advance...
#
#                         time_zone  label  californian
# 0      Pacific Time (US & Canada)    0.0          1.0
# 1     Mountain Time (US & Canada)    1.0          0.0
# 2      Pacific Time (US & Canada)    1.0          1.0
# 3      Pacific Time (US & Canada)    1.0          1.0
# 4                            None    0.0          0.0
# 5                            None    1.0          0.0
# 6                         Arizona    2.0          0.0
# 7      Pacific Time (US & Canada)    1.0          1.0
# 8                            None    1.0          0.0
# 9                            None    1.0          0.0
# 10     Pacific Time (US & Canada)    2.0          1.0
# 11     Pacific Time (US & Canada)    1.0          1.0
# 12     Pacific Time (US & Canada)    1.0          1.0
# 13                        Arizona    1.0          0.0
# 14     Pacific Time (US & Canada)    1.0          1.0
# 15                           None    1.0          0.0
# 16     Eastern Time (US & Canada)    0.0          0.0
# 17                     Georgetown    0.0          0.0
# 18     Pacific Time (US & Canada)    1.0          1.0
# 19                        Vilnius    2.0          0.0
# 20                      Stockholm    1.0          0.0
# 21     Pacific Time (US & Canada)    0.0          1.0
# 22                           None    1.0          0.0
# 23     Pacific Time (US & Canada)    1.0          1.0
# 24     Eastern Time (US & Canada)    1.0          0.0
# 25                           None    1.0          0.0
# 26                           None    1.0          0.0
# 27     Pacific Time (US & Canada)    1.0          1.0
# 28                         Alaska    1.0          0.0
# 29    Mountain Time (US & Canada)    0.0          0.0
# ...                           ...    ...          ...
# 3348                         None    1.0          0.0
# 3349                Europe/London    1.0          0.0
# 3350                         None    1.0          0.0
# 3351                         None    0.0          0.0
# 3352                         None    0.0          0.0
# 3353                         None    0.0          0.0
# 3354                         None    0.0          0.0
# 3355                         None    1.0          0.0
# 3356                         None    1.0          0.0
# 3357   Pacific Time (US & Canada)    0.0          1.0
# 3358   Eastern Time (US & Canada)    1.0          0.0
# 3359   Pacific Time (US & Canada)    1.0          1.0
# 3360                       Alaska    1.0          0.0
# 3361   Pacific Time (US & Canada)    1.0          1.0
# 3362                         None    1.0          0.0
# 3363   Pacific Time (US & Canada)    1.0          1.0
# 3364   Pacific Time (US & Canada)    1.0          1.0
# 3365                         None    1.0          0.0
# 3366   Pacific Time (US & Canada)    1.0          1.0
# 3367   Pacific Time (US & Canada)    1.0          1.0
# 3368   Pacific Time (US & Canada)    1.0          1.0
# 3369   Pacific Time (US & Canada)    1.0          1.0
# 3370   Pacific Time (US & Canada)    1.0          1.0
# 3371          America/Los_Angeles    0.0          0.0
# 3372          America/Los_Angeles    1.0          0.0
# 3373   Pacific Time (US & Canada)    1.0          1.0
# 3374                         None    0.0          0.0
# 3375   Pacific Time (US & Canada)    0.0          1.0
# 3376   Eastern Time (US & Canada)    1.0          0.0
# 3377   Pacific Time (US & Canada)    1.0          1.0
#
# [3378 rows x 7 columns]

# %%
#recategorize neutral as non-support
SBdf['label']=SBdf.label.replace(2.0,0.0)

# %%
SBdf
# Out:
#      followers_count                             location      screen_name  \
# 0               2989                    San Francisco, CA      beyondchron
# 1               2356                 Salt Lake City, Utah          MRC_SLC
# 2               1197                    San Francisco, CA    marcus_ismael
# 3                510                      Los Angeles, CA          Asmarcd
# 4                661                      California, USA   HousingHumanRt
# 5                797                        San Diego, CA      msmayarosas
# 6               1201        South LA, Boyle Hts, & beyond    sahrasulaiman
# 7               3797                        San Francisco         sutrofog
# 8               1677                     sutherland Shire  donaldh66287394
# 9                911                       Washington, DC   vanessabcalder
# 10             11869                       Sacramento, CA       dillonliam
# 11              4709                         Berkeley, CA         mateosfo
# 12               110                            BUF ➡️ LA   darryl_granger
# 13               494                          Oakland, CA     KyleAPennell
# 14               538                        San Francisco           torque
# 15              3287                 The Space Force Core    nyc_data_geek
# 16              2480           from Cleveland, in Oakland       dsmpowered
# 17               322                              Atlanta        TroyWhyte
# 18               695                           LA LA Land      melyssablue
# 19               425                              Vilnius          mgedmin
# 20              1629                  Bandis.Stockholm.se           GuSv01
# 21              4405            ÜT: 34.041042,-118.191894      kmontenegro
# 22               150                                              kdhively
# 23             33090                        San Francisco  SFBusinessTimes
# 24              3785                         Brooklyn, NY             mtsw
# 25                82                                              jcubsden
# 26              5486            L.A.via WashHts/HarlemNYC       tanlogadas
# 27             46886            San Francisco, California     Scott_Wiener
# 28               449                      Los Angeles, CA       cshepherds
# 29               483                        Mile High, CO     namhenderson
# ...              ...                                  ...              ...
# 3348              62                                       freddynietzschy
# 3349           27076  https://youtube.com/invisiblepeople     hardlynormal
# 3350              18                      Forest Hill Hex    ForestHillExt
# 3351              24                                       constituents381
# 3352             277                Van Nuys, Los Angeles     VoteForRoger
# 3353             153                         Berkeley, CA       mrlewis125
# 3354             365                          Los Angeles       jacobwooch
# 3355              12                             USA, USA   EpiphyteCities
# 3356              58                      Los Angeles, CA    DaShoeMonstar
# 3357            1370                   San Francisco, CA      marymcnamara
# 3358             431                    San Francisco, CA       irishbryan
# 3359            5238                        San Diego, CA  LisaHalverstadt
# 3360            7928                           Sacramento  MelodyGutierrez
# 3361             981                                          TaupeAvenger
# 3362              33                                          CAACentralCA
# 3363            1007                          Los Angeles       DuboffJess
# 3364            2936                    San Francisco, CA            SFHAC
# 3365             521                                            aceckhouse
# 3366            2168                          Oakland, CA   CitizenCassidy
# 3367             342                      Los Angeles, CA      nbousfield_
# 3368            1370                   San Francisco, CA      marymcnamara
# 3369            4739                       Sacramento, CA         Calefati
# 3370             227                    San Francisco, ca           donjay
# 3371            1597                      Los Angeles, CA       CleftClips
# 3372            1757                                          Saferhermosa
# 3373            2936                    San Francisco, CA            SFHAC
# 3374              11                                            JamesAria1
# 3375             340                        San Francisco        gillibits
# 3376            1195                     Toronto, Ontario  VoteTimGrantGPO
# 3377             243        Portland, OR Metopolitan Area         BranBrez
#
#                                                    text  \
# 0     Absolutely. And for all the fighting in SF, th...
# 1     RT @Tracktwentynine: Is it sad that the most t...
# 2     RT @Scott_Wiener: 2/4 Jane Kim claims #SB827 a...
# 3     #Cities, if you were really upset about what #...
# 4     Housing Is A Human Right &amp; many other hous...
# 5     RT @cayimby: Profound thanks to Sen. @Scott_Wi...
# 6     RT @dillonliam: It’s officially dead #SB827. F...
# 7     RT @mikevladimer: @MarkLeno @AaronPeskin I gre...
# 8     RT @AlexSteffen: The single most powerful solu...
# 9     "The larger issue is that too many Democrats h...
# 10    One Senator speaking, one Senator opposed. Dem...
# 11    RT @michaeldlane: Boom!💥 Real progressives wo...
# 12    RT @cayimby: Your urgent advocacy for #SB827 m...
# 13                                #SB827 is dead. Dang.
# 14    RT @Scott_Wiener: 3/4 Angela Alioto is a good ...
# 15    RT @AlexSteffen: The early defeat of #SB827, C...
# 16    RT @damienISgoodmon: If a Senator w/a history ...
# 17    RT @byJoshuaDavis: Some white politicians are ...
# 18    RT @cayimby: “Legislator after legislator talk...
# 19    RT @uhshanti: I'm just hashtagging #SB827 so p...
# 20    RT @schmangee: I wonder if the Federal Transit...
# 21    RT @TenantsTogether: Anya at @Western_Center: ...
# 22    RT @theoverheadwire: This is the building that...
# 23    .@Scott_Wiener's housing-transit measure #SB82...
# 24    RT @SFyimby: Legislators seem to be letting th...
# 25    RT @justupthepike: #SB827 is already changing ...
# 26    RT @turbolars: to anyone in the #SanFrancisco ...
# 27    The @latimes opposed #SB827 because it actuall...
# 28    RT @EthanElkind: When #SB827 came out, I was a...
# 29    RT @ariellesallai: Thank fuck #SB827 is dead a...
# ...                                                 ...
# 3348  But then our body, as a saint in the backgroun...
# 3349  RT @rbramson: I feel like with the recent demi...
# 3350  RT @Scott_Wiener: Today #SB827 did not advance...
# 3351  @kimmaicutler CA needs to stop giving into the...
# 3352  RT @HousingHumanRt: And it's dead! Scott Wiene...
# 3353  RT @HousingHumanRt: And finally @BenAllenCA gi...
# 3354  RT @damienISgoodmon: The only votes sponsors @...
# 3355  RT @graue: If you support housing and transit ...
# 3356  RT @cayimby: Legislator after legislator talke...
# 3357  RT @jillstewart: Scott Wiener just praised his...
# 3358  RT @Scott_Wiener: 1/4 Leadership starts with b...
# 3359  RT @dillonliam: My first take on the demise of...
# 3360  .@Scott_Wiener now here and is about to take u...
# 3361  RT @aceckhouse: This bill is controversial bec...
# 3362  @Scott_Wiener @NeverSassyLaura. @yimbyaction\n...
# 3363  Reference to Rubio #CEQA bill by @TedGaines .....
# 3364  RT @HousingTrustSV: https://t.co/bZKLOrXai4 Th...
# 3365  lol Senator Beall is not pleased about Vice-Ma...
# 3366  RT @JerryJonesICLC: California's #SB827 is dea...
# 3367  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3368  RT @dillonliam: You may have heard that the co...
# 3369  Just walked into the @CALmatters office at 8:2...
# 3370  RT @Scott_Wiener: The @latimes opposed #SB827 ...
# 3371  RT @ramez: I 100% agree with Alex. #SB827 was ...
# 3372  RT @Scott_Wiener: “We can have all the electri...
# 3373  RT @dillonliam: 🎉It’s #SB827 day🎉 A thread t...
# 3374  RT @jillstewart: Scott Wiener bill #SB827 defe...
# 3375  RT @IanCarlton: CA's #SB827 could have increas...
# 3376  RT @salimfurth: .@mattyglesias, @ebwhamilton a...
# 3377  RT @Scott_Wiener: Today #SB827 did not advance...
#
#                         time_zone  label  californian
# 0      Pacific Time (US & Canada)    0.0          1.0
# 1     Mountain Time (US & Canada)    1.0          0.0
# 2      Pacific Time (US & Canada)    1.0          1.0
# 3      Pacific Time (US & Canada)    1.0          1.0
# 4                            None    0.0          0.0
# 5                            None    1.0          0.0
# 6                         Arizona    0.0          0.0
# 7      Pacific Time (US & Canada)    1.0          1.0
# 8                            None    1.0          0.0
# 9                            None    1.0          0.0
# 10     Pacific Time (US & Canada)    0.0          1.0
# 11     Pacific Time (US & Canada)    1.0          1.0
# 12     Pacific Time (US & Canada)    1.0          1.0
# 13                        Arizona    1.0          0.0
# 14     Pacific Time (US & Canada)    1.0          1.0
# 15                           None    1.0          0.0
# 16     Eastern Time (US & Canada)    0.0          0.0
# 17                     Georgetown    0.0          0.0
# 18     Pacific Time (US & Canada)    1.0          1.0
# 19                        Vilnius    0.0          0.0
# 20                      Stockholm    1.0          0.0
# 21     Pacific Time (US & Canada)    0.0          1.0
# 22                           None    1.0          0.0
# 23     Pacific Time (US & Canada)    1.0          1.0
# 24     Eastern Time (US & Canada)    1.0          0.0
# 25                           None    1.0          0.0
# 26                           None    1.0          0.0
# 27     Pacific Time (US & Canada)    1.0          1.0
# 28                         Alaska    1.0          0.0
# 29    Mountain Time (US & Canada)    0.0          0.0
# ...                           ...    ...          ...
# 3348                         None    1.0          0.0
# 3349                Europe/London    1.0          0.0
# 3350                         None    1.0          0.0
# 3351                         None    0.0          0.0
# 3352                         None    0.0          0.0
# 3353                         None    0.0          0.0
# 3354                         None    0.0          0.0
# 3355                         None    1.0          0.0
# 3356                         None    1.0          0.0
# 3357   Pacific Time (US & Canada)    0.0          1.0
# 3358   Eastern Time (US & Canada)    1.0          0.0
# 3359   Pacific Time (US & Canada)    1.0          1.0
# 3360                       Alaska    1.0          0.0
# 3361   Pacific Time (US & Canada)    1.0          1.0
# 3362                         None    1.0          0.0
# 3363   Pacific Time (US & Canada)    1.0          1.0
# 3364   Pacific Time (US & Canada)    1.0          1.0
# 3365                         None    1.0          0.0
# 3366   Pacific Time (US & Canada)    1.0          1.0
# 3367   Pacific Time (US & Canada)    1.0          1.0
# 3368   Pacific Time (US & Canada)    1.0          1.0
# 3369   Pacific Time (US & Canada)    1.0          1.0
# 3370   Pacific Time (US & Canada)    1.0          1.0
# 3371          America/Los_Angeles    0.0          0.0
# 3372          America/Los_Angeles    1.0          0.0
# 3373   Pacific Time (US & Canada)    1.0          1.0
# 3374                         None    0.0          0.0
# 3375   Pacific Time (US & Canada)    0.0          1.0
# 3376   Eastern Time (US & Canada)    1.0          0.0
# 3377   Pacific Time (US & Canada)    1.0          1.0
#
# [3378 rows x 7 columns]

# %%
total_support = sum(SBdf.label)/SBdf.shape[0]
total_support
# Out:
# 0.73357015985790408

# %%
Californian_support = sum(SBdf.label * SBdf.californian)/sum(SBdf.californian)
Californian_support
# Out:
# 0.71828571428571431

# %%
Non_Californian_support = sum(SBdf.label * (1-SBdf.californian))/sum(1-SBdf.californian)
Non_Californian_support
# Out:
# 0.75

# %%
total_support*.8 #this may give us some rought sense of where the true support might be with a better classifier
# Out:
# 0.58685612788632324

# %% [markdown]
# # Conclusions
#
# SB 827 seemed to have broad support on twitter with 73% of tweets supporting the bill. This likely overestimates its offline support due to the false positive that would arise from the simple classifier used as well as due to the fact that the demographics of twitter skew towards the young, well-educated urbanites who stand to benefit the most from its implementation. Nonetheless, it does suggest that there is significant support for this type of policy and that we may see an emergence of similar bills in the not too distant future.
